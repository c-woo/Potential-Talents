# %% [markdown]
# # Potential Talents

# %% [markdown]
# I will be attempting to rank potential job candidates based on a query and return a list of candidates that best fit the query. Once ranked I will be re-ranking candidates based on ideal candidates from the first list.

# %%
## import necessary libraries

import pandas as pd
import nltk
import string
import gensim
import itertools
import numpy as np
import gensim.downloader as api
from scipy import spatial
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sent2vec.vectorizer import Vectorizer
from sent2vec.splitter import Splitter
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Data Description

# %% [markdown]
# > **Id:** Unique identifier for candidate
# > **Job_title:** Job title for candidate
# > **Location:** Geographical location for candidate
# > **Connections:** Number of connections candidate has
# > **Fit:** How fit the candidate is for the role (numeric between 0-1)

# %%
df = pd.read_csv('./potential-talents - Aspiring human resources - seeking human resources.csv')
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN

# %% [markdown]
# I will be getting word vectors for each candidates job title and comparing its cosine distance with the query word vectors to find the best fitting candidates. I will use Word2Vec, BERT, GloVe and TF-IDF to see which word vectors give the closest fit to the query.

# %% [markdown]
# ## Word2Vec

# %%
## clean up data and make a list that can be run through the Word2Vec model

def word2vec_list(df, query):
    clean_list = []

    for num in range(len(df)):
        desc = df.iloc[num]['job_title']
        ## remove punctuation from job description    
        for symbol in list(string.punctuation):
            desc = desc.replace(symbol, ' ')

        ## write out acronyms for human resource positions
        desc = nltk.word_tokenize(desc)
        for word in range(len(desc)):
            if desc[word] == 'HR':
                desc[word] = 'Human Resources'
            elif desc[word] == 'CHRO':
                desc[word] = 'Chief Human Resources Officer'
            elif desc[word] == 'GPHR':
                desc[word] = 'General Professional Human Resources'
            elif desc[word] == 'SPHR':
                desc[word] = 'Senior Professional Human Resources'

            ## remove words that are not in pretrained vectors
            ## most of these words are the names of colleges
            elif desc[word] in ['EPIK', 'Celal', 'Bayar', 'Humber', 'ENGIE', 'Buckhead', 'Luxottica', 'Beneteau', 'ScottMadden', 
                                'Nortia', 'Schwan', 'Endemol', 'JTI', 'Styczynski', 'Westfield', 'Kokomo', 'Delphi', 'Loparex']:
                desc[word] = ''
            desc[word] = desc[word].lower()

        ## remove stopwords
        desc = [token for token in desc if token not in stopwords.words('english')]
        desc = [token for token in desc if not token.isdigit()]

        desc = ' '.join(desc)
        desc = nltk.word_tokenize(desc)

        clean_list.append(desc)
    
    ## tokenize query and add to list
    clean_list.append(query.lower().split())
    
    return clean_list

# %%
job_desc_list = word2vec_list(df, 'seeking human resources')

# %%
job_desc_list
# Out:
# [['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['experienced',
#   'retail',
#   'manager',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['human', 'resources', 'staffing', 'recruiting', 'professional'],
#  ['human', 'resources', 'specialist'],
#  ['director', 'human', 'resources', 'north', 'america', 'groupe'],
#  ['retired',
#   'army',
#   'national',
#   'guard',
#   'recruiter',
#   'office',
#   'manager',
#   'seeking',
#   'position',
#   'human',
#   'resources'],
#  ['human', 'resources', 'generalist', 'inc'],
#  ['business',
#   'management',
#   'major',
#   'aspiring',
#   'human',
#   'resources',
#   'manager'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'seeking',
#   'internship',
#   'human',
#   'resources'],
#  ['human', 'resources', 'professional'],
#  ['staffing',
#   'seeking',
#   'human',
#   'resources',
#   'payroll',
#   'administrative',
#   'professionals'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'passionate',
#   'helping',
#   'create',
#   'inclusive',
#   'engaging',
#   'work',
#   'environment'],
#  ['human',
#   'resources',
#   'conflict',
#   'management',
#   'policies',
#   'procedures',
#   'talent',
#   'management',
#   'benefits',
#   'compensation'],
#  ['human', 'resources', 'generalist'],
#  ['liberal', 'arts', 'major', 'aspiring', 'human', 'resources', 'analyst'],
#  ['junior', 'mes', 'engineer', 'information', 'systems'],
#  ['senior',
#   'human',
#   'resources',
#   'business',
#   'partner',
#   'heil',
#   'environmental'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'energetic',
#   'team',
#   'focused',
#   'leader'],
#  ['human', 'resources', 'manager', 'shine', 'north', 'america'],
#  ['human', 'resources', 'professional', 'world', 'leader', 'gis', 'software'],
#  ['rrp',
#   'brand',
#   'portfolio',
#   'executive',
#   'japan',
#   'tobacco',
#   'international'],
#  ['information',
#   'systems',
#   'specialist',
#   'programmer',
#   'love',
#   'data',
#   'organization'],
#  ['bachelor', 'science', 'biology', 'victoria', 'university', 'wellington'],
#  ['human', 'resources', 'management', 'major'],
#  ['director', 'human', 'resources', 'ey'],
#  ['undergraduate', 'research', 'assistant', 'lab'],
#  ['lead', 'official', 'western', 'illinois', 'university'],
#  ['seeking',
#   'employment',
#   'opportunities',
#   'within',
#   'customer',
#   'service',
#   'patient',
#   'care'],
#  ['admissions',
#   'representative',
#   'community',
#   'medical',
#   'center',
#   'long',
#   'beach'],
#  ['seeking',
#   'human',
#   'resources',
#   'opportunities',
#   'open',
#   'travel',
#   'relocation'],
#  ['student', 'state', 'university'],
#  ['student',
#   'indiana',
#   'university',
#   'business',
#   'management',
#   'retail',
#   'manager',
#   'hardware',
#   'paint'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['student'],
#  ['seeking', 'human', 'resources', 'position'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'graduating',
#   'may',
#   'seeking',
#   'entry',
#   'level',
#   'human',
#   'resources',
#   'position',
#   'st',
#   'louis'],
#  ['human', 'resources', 'generalist'],
#  ['business', 'intelligence', 'analytics', 'travelers'],
#  ['always', 'set', 'success'],
#  ['director', 'administration', 'excellence', 'logging'],
#  ['seeking', 'human', 'resources']]

# %%
## get word vectors using Google's pretrained word vectors

vectorizer = Vectorizer()
vectorizer.word2vec(job_desc_list, pretrained_vectors_path= './GoogleNews-vectors-negative300.bin')
word2vec_vectors = vectorizer.vectors

# %%
dist_1 = spatial.distance.cosine(word2vec_vectors[-1], word2vec_vectors[0])
dist_2 = spatial.distance.cosine(word2vec_vectors[-1], word2vec_vectors[2])
print('dist_1: {0}, dist-2: {1}'.format(dist_1, dist_2))
# Out:
# dist_1: 0.611827164888382, dist-2: 0.29940420389175415

# %%
## create a new dataframe to add vector fit scores

vector_df = df
vector_df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN

# %%
## append word2vec scores to dataframe

scores = []
for num in range(len(job_desc_list) - 1):
    scores.append(1 - spatial.distance.cosine(word2vec_vectors[num], word2vec_vectors[-1]))
    
vector_df['word2vec_fit'] = scores
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit  word2vec_fit
# 0                         Houston, Texas         85  NaN      0.388173
# 1                                 Kanada      500+   NaN      0.104410
# 2    Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 3                          Denton, Texas      500+   NaN      0.291818
# 4                         İzmir, Türkiye      500+   NaN      0.229988
# ..                                   ...        ...  ...           ...
# 99              Cape Girardeau, Missouri        103  NaN      0.729863
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 101           Greater New York City Area         49  NaN      0.282647
# 102             Greater Los Angeles Area      500+   NaN      0.133268
# 103                          Katy, Texas      500+   NaN      0.281777
#
# [104 rows x 6 columns]

# %%
vector_df.sort_values(by=['word2vec_fit'], ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 27    28              Seeking Human Resources Opportunities
# 29    30              Seeking Human Resources Opportunities
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 67    68            Human Resources Specialist at Luxottica
# 100  101              Human Resources Generalist at Loparex
# 77    78             Human Resources Generalist at Schwan's
# 87    88                   Human Resources Management Major
# 59    60                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
#
#                                 location connection  fit  word2vec_fit
# 98                Las Vegas, Nevada Area         48  NaN      0.920869
# 27                     Chicago, Illinois        390  NaN      0.903864
# 29                     Chicago, Illinois        390  NaN      0.903864
# 72                   Houston, Texas Area          7  NaN      0.839220
# 9              Greater Philadelphia Area      500+   NaN      0.808101
# 39             Greater Philadelphia Area      500+   NaN      0.808101
# 52             Greater Philadelphia Area      500+   NaN      0.808101
# 61             Greater Philadelphia Area      500+   NaN      0.808101
# 73                   Greater Boston Area         16  NaN      0.793325
# 67            Greater New York City Area      500+   NaN      0.767376
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 77           Amerika Birleşik Devletleri      500+   NaN      0.750962
# 87                  Milpitas, California         18  NaN      0.747540
# 59            Greater New York City Area          1  NaN      0.743151
# 5             Greater New York City Area          1  NaN      0.743151

# %% [markdown]
# It looks like the word2vec model works really well with the top fitting results returning candidates that match the query 'seeking human resources'

# %% [markdown]
# ## BERT

# %% [markdown]
# Next we'll add BERT vectors to our dataframe. The sent2vec package that I am using does not require tokenization for BERT vectors so we will not be needing to clean our data as much as we did with the Word2Vec model.

# %%
def bert_list(df, query):
    bert_list = []

    for num in range(len(df)):
        desc = df.iloc[num]['job_title']
        ## remove punctuation from job description    
        for symbol in list(string.punctuation):
            desc = desc.replace(symbol, ' ')

        ## write out acronyms for human resource positions
        desc = nltk.word_tokenize(desc)
        for word in range(len(desc)):
            if desc[word] == 'HR':
                desc[word] = 'Human Resources'
            elif desc[word] == 'CHRO':
                desc[word] = 'Chief Human Resources Officer'
            elif desc[word] == 'GPHR':
                desc[word] = 'General Professional in Human Resources'
            elif desc[word] == 'SPHR':
                desc[word] = 'Senior Professional in Human Resources'

        desc = ' '.join(desc)
        bert_list.append(desc)
        
    bert_list.append(query)
    
    return bert_list

# %%
bert_job_list = bert_list(df, 'seeking human resources')

# %%
bert_job_list
# Out:
# ['2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Aspiring Human Resources Management student seeking an internship',
#  'Seeking Human Resources Opportunities',
#  'Aspiring Human Resources Management student seeking an internship',
#  'Seeking Human Resources Opportunities',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Aspiring Human Resources Specialist',
#  'Human Resources Senior Specialist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  'Experienced Retail Manager and aspiring Human Resources Professional',
#  'Human Resources Staffing and Recruiting Professional',
#  'Human Resources Specialist at Luxottica',
#  'Director of Human Resources North America Groupe Beneteau',
#  'Retired Army National Guard Recruiter office manager seeking a position in Human Resources',
#  'Human Resources Generalist at ScottMadden Inc',
#  'Business Management Major and Aspiring Human Resources Manager',
#  'Aspiring Human Resources Manager seeking internship in Human Resources',
#  'Human Resources Professional',
#  'Nortia Staffing is seeking Human Resources Payroll Administrative Professionals 408 709 2621',
#  'Aspiring Human Resources Professional Passionate about helping to create an inclusive and engaging work environment',
#  'Human Resources Conflict Management Policies Procedures Talent Management Benefits Compensation',
#  'Human Resources Generalist at Schwan s',
#  'Liberal Arts Major Aspiring Human Resources Analyst',
#  'Junior MES Engineer Information Systems',
#  'Senior Human Resources Business Partner at Heil Environmental',
#  'Aspiring Human Resources Professional An energetic and Team Focused Leader',
#  'Human Resources Manager at Endemol Shine North America',
#  'Human Resources professional for the world leader in GIS software',
#  'RRP Brand Portfolio Executive at JTI Japan Tobacco International',
#  'Information Systems Specialist and Programmer with a love for data and organization',
#  'Bachelor of Science in Biology from Victoria University of Wellington',
#  'Human Resources Management Major',
#  'Director Human Resources at EY',
#  'Undergraduate Research Assistant at Styczynski Lab',
#  'Lead Official at Western Illinois University',
#  'Seeking employment opportunities within Customer Service or Patient Care',
#  'Admissions Representative at Community medical center long beach',
#  'Seeking Human Resources Opportunities Open to travel and relocation',
#  'Student at Westfield State University',
#  'Student at Indiana University Kokomo Business Management Retail Manager at Delphi Hardware and Paint',
#  'Aspiring Human Resources Professional',
#  'Student',
#  'Seeking Human Resources Position',
#  'Aspiring Human Resources Manager Graduating May 2020 Seeking an Entry Level Human Resources Position in St Louis',
#  'Human Resources Generalist at Loparex',
#  'Business Intelligence and Analytics at Travelers',
#  'Always set them up for Success',
#  'Director Of Administration at Excellence Logging',
#  'seeking human resources']

# %%
vectorizer = Vectorizer()
vectorizer.bert(bert_job_list)
bert_vectors = vectorizer.vectors
# Out:
# Vectorization done on cpu device
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
dist_1 = spatial.distance.cosine(bert_vectors[-1], bert_vectors[0])
dist_2 = spatial.distance.cosine(bert_vectors[-1], bert_vectors[2])
print('dist_1: {0}, dist-2: {1}'.format(dist_1, dist_2))
# Out:
# dist_1: 0.07078111171722412, dist-2: 0.01500558853149414

# %%
scores = []
for num in range(len(bert_job_list) - 1):
    scores.append(1 - spatial.distance.cosine(bert_vectors[num], bert_vectors[-1]))
    
vector_df['bert_fit'] = scores
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit  word2vec_fit  \
# 0                         Houston, Texas         85  NaN      0.388173
# 1                                 Kanada      500+   NaN      0.104410
# 2    Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 3                          Denton, Texas      500+   NaN      0.291818
# 4                         İzmir, Türkiye      500+   NaN      0.229988
# ..                                   ...        ...  ...           ...
# 99              Cape Girardeau, Missouri        103  NaN      0.729863
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 101           Greater New York City Area         49  NaN      0.282647
# 102             Greater Los Angeles Area      500+   NaN      0.133268
# 103                          Katy, Texas      500+   NaN      0.281777
#
#      bert_fit
# 0    0.929219
# 1    0.948172
# 2    0.984994
# 3    0.973138
# 4    0.935457
# ..        ...
# 99   0.914459
# 100  0.982065
# 101  0.976543
# 102  0.983066
# 103  0.968243
#
# [104 rows x 7 columns]

# %%
vector_df.sort_values(by=['bert_fit'], ascending=False).head(15)
# Out:
#     id                              job_title  \
# 29  30  Seeking Human Resources Opportunities
# 27  28  Seeking Human Resources Opportunities
# 98  99       Seeking Human Resources Position
# 73  74           Human Resources Professional
# 87  88       Human Resources Management Major
# 5    6    Aspiring Human Resources Specialist
# 59  60    Aspiring Human Resources Specialist
# 35  36    Aspiring Human Resources Specialist
# 48  49    Aspiring Human Resources Specialist
# 23  24    Aspiring Human Resources Specialist
# 97  98                                Student
# 32  33  Aspiring Human Resources Professional
# 20  21  Aspiring Human Resources Professional
# 96  97  Aspiring Human Resources Professional
# 2    3  Aspiring Human Resources Professional
#
#                                location connection  fit  word2vec_fit  \
# 29                    Chicago, Illinois        390  NaN      0.903864
# 27                    Chicago, Illinois        390  NaN      0.903864
# 98               Las Vegas, Nevada Area         48  NaN      0.920869
# 73                  Greater Boston Area         16  NaN      0.793325
# 87                 Milpitas, California         18  NaN      0.747540
# 5            Greater New York City Area          1  NaN      0.743151
# 59           Greater New York City Area          1  NaN      0.743151
# 35           Greater New York City Area          1  NaN      0.743151
# 48           Greater New York City Area          1  NaN      0.743151
# 23           Greater New York City Area          1  NaN      0.743151
# 97                  Houston, Texas Area          4  NaN      0.123904
# 32  Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 20  Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 96                 Kokomo, Indiana Area         71  NaN      0.700596
# 2   Raleigh-Durham, North Carolina Area         44  NaN      0.700596
#
#     bert_fit
# 29  0.996201
# 27  0.996201
# 98  0.994894
# 73  0.991686
# 87  0.990193
# 5   0.987985
# 59  0.987985
# 35  0.987985
# 48  0.987985
# 23  0.987985
# 97  0.985903
# 32  0.984994
# 20  0.984994
# 96  0.984994
# 2   0.984994

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# Next we'll add TF-IDF vectors to our dataframe.

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(bert_job_list)

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
vector_df['tfidf_fit'] = cosine_sim[-1][:-1]

# %%
vector_df.sort_values(by=['tfidf_fit'], ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 27  28              Seeking Human Resources Opportunities
# 29  30              Seeking Human Resources Opportunities
# 98  99                   Seeking Human Resources Position
# 72  73  Aspiring Human Resources Manager, seeking inte...
# 52  53  Seeking Human Resources HRIS and Generalist Po...
# 9   10  Seeking Human Resources HRIS and Generalist Po...
# 61  62  Seeking Human Resources HRIS and Generalist Po...
# 39  40  Seeking Human Resources HRIS and Generalist Po...
# 26  27  Aspiring Human Resources Management student se...
# 28  29  Aspiring Human Resources Management student se...
# 73  74                       Human Resources Professional
# 93  94  Seeking Human  Resources Opportunities. Open t...
# 32  33              Aspiring Human Resources Professional
# 2    3              Aspiring Human Resources Professional
# 96  97              Aspiring Human Resources Professional
#
#                                location connection  fit  word2vec_fit  \
# 27                    Chicago, Illinois        390  NaN      0.903864
# 29                    Chicago, Illinois        390  NaN      0.903864
# 98               Las Vegas, Nevada Area         48  NaN      0.920869
# 72                  Houston, Texas Area          7  NaN      0.839220
# 52            Greater Philadelphia Area      500+   NaN      0.808101
# 9             Greater Philadelphia Area      500+   NaN      0.808101
# 61            Greater Philadelphia Area      500+   NaN      0.808101
# 39            Greater Philadelphia Area      500+   NaN      0.808101
# 26                  Houston, Texas Area      500+   NaN      0.696512
# 28                  Houston, Texas Area      500+   NaN      0.696512
# 73                  Greater Boston Area         16  NaN      0.793325
# 93          Amerika Birleşik Devletleri        415  NaN      0.726077
# 32  Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 2   Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 96                 Kokomo, Indiana Area         71  NaN      0.700596
#
#     bert_fit  tfidf_fit
# 27  0.996201   0.646155
# 29  0.996201   0.646155
# 98  0.994894   0.625865
# 72  0.975402   0.552318
# 52  0.974998   0.447527
# 9   0.974998   0.447527
# 61  0.974998   0.447527
# 39  0.974998   0.447527
# 26  0.965308   0.406702
# 28  0.965308   0.406702
# 73  0.991686   0.351856
# 93  0.969101   0.302663
# 32  0.984994   0.292820
# 2   0.984994   0.292820
# 96  0.984994   0.292820

# %% [markdown]
# ## GloVe

# %% [markdown]
# Finally we'll add GloVe vectors to the dataframe. We will be using pretrained glove embeddings to get our word vectors.

# %%
def glove_list(df, query):
    glove_list = []

    for num in range(len(df)):
        desc = df.iloc[num]['job_title']
        ## remove punctuation from job description    
        for symbol in list(string.punctuation):
            desc = desc.replace(symbol, ' ')

        ## write out acronyms for human resource positions
        desc = nltk.word_tokenize(desc)
        for word in range(len(desc)):
            if desc[word] == 'HR':
                desc[word] = 'Human Resources'
            elif desc[word] == 'CHRO':
                desc[word] = 'Chief Human Resources Officer'
            elif desc[word] == 'GPHR':
                desc[word] = 'General Professional in Human Resources'
            elif desc[word] == 'SPHR':
                desc[word] = 'Senior Professional in Human Resources'
            ## remove words not found in pretrained embeddings
            elif desc[word] in ['HRIS', 'ENGIE', 'ScottMadden', 'Styczynski', 'Nortia', 'Loparex']:
                desc[word] = ''
            desc[word] = desc[word].lower()

        desc = [token for token in desc if token not in stopwords.words('english')]
        desc = [token for token in desc if not token.isdigit()]

        desc = ' '.join(desc)
        desc = nltk.word_tokenize(desc)
        glove_list.append(desc)

    glove_list.append(query.lower().split())
    
    return glove_list

# %%
glove_job_list = glove_list(df, 'seeking human resources')
glove_job_list
# Out:
# [['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'epik', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'celal', 'bayar', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resources',
#   'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resources',
#   'generalist'],
#  ['seeking', 'human', 'resources', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'in',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'in',
#   'human',
#   'resources'],
#  ['human',
#   'resources',
#   'coordinator',
#   'intercontinental',
#   'buckhead',
#   'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'epik', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'epik', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'celal', 'bayar', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resources',
#   'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'epik', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'celal', 'bayar', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resources',
#   'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resources',
#   'generalist'],
#  ['seeking', 'human', 'resources', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'in',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'in',
#   'human',
#   'resources'],
#  ['human',
#   'resources',
#   'coordinator',
#   'intercontinental',
#   'buckhead',
#   'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'epik', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'celal', 'bayar', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resources',
#   'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student',
#   'humber',
#   'college',
#   'aspiring',
#   'human',
#   'resources',
#   'generalist'],
#  ['seeking', 'human', 'resources', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'in',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'in',
#   'human',
#   'resources'],
#  ['human',
#   'resources',
#   'coordinator',
#   'intercontinental',
#   'buckhead',
#   'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['seeking', 'human', 'resources', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'in',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'in',
#   'human',
#   'resources'],
#  ['human',
#   'resources',
#   'coordinator',
#   'intercontinental',
#   'buckhead',
#   'atlanta'],
#  ['experienced',
#   'retail',
#   'manager',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['human', 'resources', 'staffing', 'recruiting', 'professional'],
#  ['human', 'resources', 'specialist', 'luxottica'],
#  ['director', 'human', 'resources', 'north', 'america', 'groupe', 'beneteau'],
#  ['retired',
#   'army',
#   'national',
#   'guard',
#   'recruiter',
#   'office',
#   'manager',
#   'seeking',
#   'position',
#   'human',
#   'resources'],
#  ['human', 'resources', 'generalist', 'inc'],
#  ['business',
#   'management',
#   'major',
#   'aspiring',
#   'human',
#   'resources',
#   'manager'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'seeking',
#   'internship',
#   'human',
#   'resources'],
#  ['human', 'resources', 'professional'],
#  ['staffing',
#   'seeking',
#   'human',
#   'resources',
#   'payroll',
#   'administrative',
#   'professionals'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'passionate',
#   'helping',
#   'create',
#   'inclusive',
#   'engaging',
#   'work',
#   'environment'],
#  ['human',
#   'resources',
#   'conflict',
#   'management',
#   'policies',
#   'procedures',
#   'talent',
#   'management',
#   'benefits',
#   'compensation'],
#  ['human', 'resources', 'generalist', 'schwan'],
#  ['liberal', 'arts', 'major', 'aspiring', 'human', 'resources', 'analyst'],
#  ['junior', 'mes', 'engineer', 'information', 'systems'],
#  ['senior',
#   'human',
#   'resources',
#   'business',
#   'partner',
#   'heil',
#   'environmental'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'energetic',
#   'team',
#   'focused',
#   'leader'],
#  ['human', 'resources', 'manager', 'endemol', 'shine', 'north', 'america'],
#  ['human', 'resources', 'professional', 'world', 'leader', 'gis', 'software'],
#  ['rrp',
#   'brand',
#   'portfolio',
#   'executive',
#   'jti',
#   'japan',
#   'tobacco',
#   'international'],
#  ['information',
#   'systems',
#   'specialist',
#   'programmer',
#   'love',
#   'data',
#   'organization'],
#  ['bachelor', 'science', 'biology', 'victoria', 'university', 'wellington'],
#  ['human', 'resources', 'management', 'major'],
#  ['director', 'human', 'resources', 'ey'],
#  ['undergraduate', 'research', 'assistant', 'lab'],
#  ['lead', 'official', 'western', 'illinois', 'university'],
#  ['seeking',
#   'employment',
#   'opportunities',
#   'within',
#   'customer',
#   'service',
#   'patient',
#   'care'],
#  ['admissions',
#   'representative',
#   'community',
#   'medical',
#   'center',
#   'long',
#   'beach'],
#  ['seeking',
#   'human',
#   'resources',
#   'opportunities',
#   'open',
#   'travel',
#   'relocation'],
#  ['student', 'westfield', 'state', 'university'],
#  ['student',
#   'indiana',
#   'university',
#   'kokomo',
#   'business',
#   'management',
#   'retail',
#   'manager',
#   'delphi',
#   'hardware',
#   'paint'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['student'],
#  ['seeking', 'human', 'resources', 'position'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'graduating',
#   'may',
#   'seeking',
#   'entry',
#   'level',
#   'human',
#   'resources',
#   'position',
#   'st',
#   'louis'],
#  ['human', 'resources', 'generalist'],
#  ['business', 'intelligence', 'analytics', 'travelers'],
#  ['always', 'set', 'success'],
#  ['director', 'administration', 'excellence', 'logging'],
#  ['seeking', 'human', 'resources']]

# %%
## we will be downloading pretrained GloVe embeddings which has been trained on Wikipedia using gensim

model = api.load("glove-wiki-gigaword-300")

# %%
## create a function to get word vectors using the gensim model

def get_vector(s):
    return np.sum(np.array([model[i] for i in s]), axis=0)

# %%
glove_vectors = []

for num in range(len(glove_job_list)):
    glove_vectors.append(get_vector(glove_job_list[num]))

# %%
glove_vectors
# Out:
# [array([ 1.5282625 ,  3.2461998 ,  0.10179698,  0.43414286, -1.1617588 ,
#          0.42638186, -1.2995371 , -2.175614  , -1.2447441 , -8.75541   ,
#          2.066736  ,  3.179113  ,  1.047955  , -1.439763  ,  0.32221   ,
#          2.150875  ,  0.134926  ,  0.38139823,  0.97562855, -2.576674  ,
#         -2.153926  ,  1.1725923 ,  0.6002661 ,  3.276764  , -2.073533  ,
#          2.584117  ,  3.2218032 ,  2.790596  ,  0.09734902, -3.9332678 ,
#          1.0110134 , -1.9817    ,  0.35711497,  0.30539995, -6.045522  ,
#         -0.35889903, -0.39025107,  0.576265  , -0.925467  , -0.43875903,
#          0.46786496, -1.8324845 , -0.24037302,  2.687144  , -0.933758  ,
#         -1.515815  ,  3.75725   ,  4.4700537 ,  2.0354638 , -4.00129   ,
#         -1.041018  ,  0.926556  ,  1.005497  ,  0.06708105, -0.4698538 ,
#         -1.8851821 ,  3.2804098 , -1.1563601 , -0.366996  ,  0.54470396,
#          1.0268004 ,  2.4263701 ,  2.331198  ,  0.21122198, -0.24890622,
#         -1.463427  , -0.04659796,  0.23804508,  0.20644096, -2.5534048 ,
#          0.674886  , -0.27946985, -0.605196  ,  0.75944793, -3.5195532 ,
#          1.2387407 , -0.57455   ,  0.06698996,  1.0212457 ,  1.4221402 ,
#          3.656123  , -1.1580615 , -0.5621178 , -3.7765682 ,  1.8785095 ,
#          0.12596695,  0.3797504 , -1.0770328 , -2.698427  ,  0.48482993,
#         -1.498029  ,  2.648801  , -0.07559098, -0.39648294,  1.2288027 ,
#         -0.16841197, -1.116705  , -2.3709958 , -2.8850226 , -2.1156602 ,
#         -1.5186951 , -0.580681  , -2.2620502 ,  2.0899217 , -0.53128505,
#         -1.1645631 ,  3.1377704 ,  1.0135219 , -1.0372021 , -1.1424291 ,
#         -0.61924183, -4.0316944 , -1.3601959 , -1.2824401 ,  1.429352  ,
#         -0.54943603, -0.48410055, -1.088262  , -0.8762756 ,  2.477195  ,
#          1.747237  ,  5.097984  , -1.5100331 ,  0.702723  , -0.68104994,
#          0.07526196,  1.8975608 ,  0.06199594,  1.823283  , -1.2632151 ,
#         -0.47398946, -4.07054   ,  0.648966  , -4.9242854 ,  0.974344  ,
#         -3.1266463 , -2.703502  ,  0.30844697, -4.347099  ,  0.33933902,
#          4.856428  ,  1.0510991 ,  1.1248571 , -2.69747   ,  3.6647618 ,
#          0.71016   ,  2.170549  , -2.297656  , -1.183239  ,  0.95450914,
#          7.6639094 ,  0.03343496,  1.9881475 , -0.30428106, -0.18876904,
#         -0.38335872, -2.0516348 , -1.424772  ,  1.5783079 , -1.3645921 ,
#          7.33830035e-02, -3.81100029e-01,  5.98780036e-01,  1.79302645e+00,
#         -2.66005993e-01,  7.90199995e-01, -1.76001802e-01,  5.37901998e-01,
#         -8.56209993e-01,  8.61330032e-02, -4.81400013e-01,  4.91171986e-01,
#         -8.92739892e-02, -1.08672798e+00, -5.39032996e-01,  6.56639993e-01,
#         -1.34414995e+00,  4.49942023e-01,  3.57500166e-02,  5.95500022e-02,
#          6.44324064e-01, -2.71569937e-02, -2.44500011e-01, -3.05210203e-02,
#         -4.63149995e-01, -2.10409999e-01, -7.03050017e-01, -8.76700044e-01,
#         -2.33118013e-01,  1.33999002e+00,  1.85434008e+00, -5.65598965e-01,
#         -2.32210016e+00, -4.71817553e-02,  9.62059975e-01,  2.42000073e-03,
#          8.86569992e-02,  7.22633004e-01,  1.04318000e-01, -4.30149972e-01,
#          4.92119998e-01, -5.34680009e-01,  1.22230327e+00, -1.36900246e-02,
#         -7.07521200e-01, -7.95089960e-01, -8.08730006e-01,  1.13972008e+00,
#          2.35620990e-01, -4.56952006e-01,  8.84249806e-02,  2.15114981e-01,
#          7.80470014e-01,  1.27379000e+00, -5.38893998e-01,  4.10652995e-01,
#         -1.39640003e-01,  6.10710025e-01, -7.40389973e-02,  2.55573988e-01,
#          3.99751991e-01,  2.41609961e-02, -3.17908674e-01,  1.95018977e-01,
#         -5.88280010e+00,  6.07609987e-01,  2.68333006e+00, -4.36345994e-01,
#         -5.76905966e-01, -1.00012994e+00,  4.75367993e-01,  6.15684986e-01,
#         -4.99669999e-01, -1.34889698e+00,  4.12674010e-01,  8.84541035e-01,
#          8.58969986e-01, -1.51559949e-01, -1.21027005e+00, -1.33306003e+00,
#          3.46648514e-01,  3.83540004e-01,  2.96425998e-01,  2.00376987e+00,
#         -4.47148025e-01, -4.76284027e-01, -1.22563995e-01, -2.24609971e-02],
#        dtype=float32)]

# %%
scores = []
for num in range(len(glove_job_list) - 1):
    scores.append(1 - spatial.distance.cosine(glove_vectors[num], glove_vectors[-1]))
    
vector_df['glove_fit'] = scores
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit  word2vec_fit  \
# 0                         Houston, Texas         85  NaN      0.388173
# 1                                 Kanada      500+   NaN      0.104410
# 2    Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 3                          Denton, Texas      500+   NaN      0.291818
# 4                         İzmir, Türkiye      500+   NaN      0.229988
# ..                                   ...        ...  ...           ...
# 99              Cape Girardeau, Missouri        103  NaN      0.729863
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 101           Greater New York City Area         49  NaN      0.282647
# 102             Greater Los Angeles Area      500+   NaN      0.133268
# 103                          Katy, Texas      500+   NaN      0.281777
#
#      bert_fit  tfidf_fit  glove_fit
# 0    0.929219   0.097827   0.466585
# 1    0.948172   0.000000   0.329688
# 2    0.984994   0.292820   0.799220
# 3    0.973138   0.000000   0.529448
# 4    0.935457   0.000000   0.295936
# ..        ...        ...        ...
# 99   0.914459   0.283608   0.809268
# 100  0.982065   0.172445   0.810235
# 101  0.976543   0.000000   0.412289
# 102  0.983066   0.000000   0.459518
# 103  0.968243   0.000000   0.526039
#
# [104 rows x 9 columns]

# %%
vector_df.sort_values(by=['glove_fit'], ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 29  30              Seeking Human Resources Opportunities
# 27  28              Seeking Human Resources Opportunities
# 98  99                   Seeking Human Resources Position
# 72  73  Aspiring Human Resources Manager, seeking inte...
# 52  53  Seeking Human Resources HRIS and Generalist Po...
# 9   10  Seeking Human Resources HRIS and Generalist Po...
# 39  40  Seeking Human Resources HRIS and Generalist Po...
# 61  62  Seeking Human Resources HRIS and Generalist Po...
# 73  74                       Human Resources Professional
# 87  88                   Human Resources Management Major
# 93  94  Seeking Human  Resources Opportunities. Open t...
# 5    6                Aspiring Human Resources Specialist
# 35  36                Aspiring Human Resources Specialist
# 59  60                Aspiring Human Resources Specialist
# 23  24                Aspiring Human Resources Specialist
#
#                        location connection  fit  word2vec_fit  bert_fit  \
# 29            Chicago, Illinois        390  NaN      0.903864  0.996201
# 27            Chicago, Illinois        390  NaN      0.903864  0.996201
# 98       Las Vegas, Nevada Area         48  NaN      0.920869  0.994894
# 72          Houston, Texas Area          7  NaN      0.839220  0.975402
# 52    Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 9     Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 39    Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 61    Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 73          Greater Boston Area         16  NaN      0.793325  0.991686
# 87         Milpitas, California         18  NaN      0.747540  0.990193
# 93  Amerika Birleşik Devletleri        415  NaN      0.726077  0.969101
# 5    Greater New York City Area          1  NaN      0.743151  0.987985
# 35   Greater New York City Area          1  NaN      0.743151  0.987985
# 59   Greater New York City Area          1  NaN      0.743151  0.987985
# 23   Greater New York City Area          1  NaN      0.743151  0.987985
#
#     tfidf_fit  glove_fit
# 29   0.646155   0.948254
# 27   0.646155   0.948254
# 98   0.625865   0.945992
# 72   0.552318   0.914078
# 52   0.447527   0.873041
# 9    0.447527   0.873041
# 39   0.447527   0.873041
# 61   0.447527   0.873041
# 73   0.351856   0.864729
# 87   0.183370   0.849824
# 93   0.302663   0.849721
# 5    0.261115   0.841785
# 35   0.261115   0.841785
# 59   0.261115   0.841785
# 23   0.261115   0.841785

# %%
vector_df.drop('fit', axis=1, inplace=True)
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  word2vec_fit  bert_fit  \
# 0                         Houston, Texas         85      0.388173  0.929219
# 1                                 Kanada      500+       0.104410  0.948172
# 2    Raleigh-Durham, North Carolina Area         44      0.700596  0.984994
# 3                          Denton, Texas      500+       0.291818  0.973138
# 4                         İzmir, Türkiye      500+       0.229988  0.935457
# ..                                   ...        ...           ...       ...
# 99              Cape Girardeau, Missouri        103      0.729863  0.914459
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962  0.982065
# 101           Greater New York City Area         49      0.282647  0.976543
# 102             Greater Los Angeles Area      500+       0.133268  0.983066
# 103                          Katy, Texas      500+       0.281777  0.968243
#
#      tfidf_fit  glove_fit
# 0     0.097827   0.466585
# 1     0.000000   0.329688
# 2     0.292820   0.799220
# 3     0.000000   0.529448
# 4     0.000000   0.295936
# ..         ...        ...
# 99    0.283608   0.809268
# 100   0.172445   0.810235
# 101   0.000000   0.412289
# 102   0.000000   0.459518
# 103   0.000000   0.526039
#
# [104 rows x 8 columns]

# %% [markdown]
# Now that I have all the fit scores, I took a look at each models top results and have concluded that the Word2Vec vectors provide the best fit for the query. I will be using that to create the RankNet model.

# %% [markdown]
# ## RankNet

# %%
## create numpy arrays of the word2vec vectors as input data and the fit scores as the target variable

X = pd.DataFrame(word2vec_vectors)
y = np.array(vector_df['word2vec_fit'])

# %%
## drop the query string from the input data
X.drop([104], inplace=True)

## I need to create a numpy array for query id, in this case we only have 1 query id so I will be creating a numpy array 
## with the same number of rows as our input data with 1's to group the data together
X['qid'] = 1
qid = np.array(X['qid'])

## drop the query id from input data
X.drop('qid', axis=1, inplace=True)
X = X.to_numpy()

# %%
X
# Out:
# array([[-0.06260172,  0.0594991 ,  0.01339213, ..., -0.0257899 ,
#         -0.01607577,  0.10813395],
#        [ 0.0164388 ,  0.0230306 ,  0.06384277, ...,  0.03059896,
#          0.00439453,  0.02514648],
#        [-0.09277344,  0.03723145,  0.08280945, ..., -0.04348755,
#         -0.08966064,  0.03756714],
#        ...,
#        [ 0.18185425, -0.05010986, -0.08358765, ...,  0.0144043 ,
#          0.13219261,  0.0296936 ],
#        [ 0.01285807,  0.10728963,  0.02231852, ...,  0.00384521,
#          0.00382487, -0.1295573 ],
#        [-0.0721283 , -0.02363586,  0.03528214, ...,  0.01784515,
#          0.1071167 ,  0.14154053]], dtype=float32)

# %%
## run the data through the RankNet model

from LambdaRankNN  import RankNetNN

ranker = RankNetNN(input_size=X.shape[1], hidden_layer_sizes=(128, 64,), activation=('relu', 'relu',))
ranker.fit(X, y, qid, epochs=35)
# Out:
# Epoch 1/20
# 163/163 [==============================] - 1s 1ms/step - loss: 0.1600
# Epoch 2/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0405
# Epoch 3/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0256
# Epoch 4/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0177
# Epoch 5/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0186
# Epoch 6/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 7/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0199
# Epoch 8/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0148
# Epoch 9/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 10/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0112
# Epoch 11/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0160
# Epoch 12/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 13/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 14/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0067
# Epoch 15/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 16/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 17/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0110
# Epoch 18/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 19/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 20/20
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0090
# ndcg: 0.9999550217795616

# %%
pred = ranker.predict(X)
pred
# Out:
# array([-27.791878 , -96.43367  ,  40.360817 , -38.84929  , -62.30091  ,
#         53.04063  ,   1.6328974,  40.892204 ,   1.6328974,  70.12957  ,
#        -72.92934  ,  31.001757 ,  10.664214 , -27.791878 , -27.791878 ,
#        -96.43367  ,  40.360817 , -38.84929  , -27.791878 , -96.43367  ,
#         40.360817 , -38.84929  , -62.30091  ,  53.04063  ,   1.6328974,
#         40.892204 ,  32.651554 ,  88.92209  ,  32.651554 ,  88.92209  ,
#        -27.791878 , -96.43367  ,  40.360817 , -38.84929  , -62.30091  ,
#         53.04063  ,   1.6328974,  40.892204 ,   1.6328974,  70.12957  ,
#        -72.92934  ,  31.001757 ,  10.664214 , -27.791878 , -96.43367  ,
#         40.360817 , -38.84929  , -62.30091  ,  53.04063  ,   1.6328974,
#         40.892204 ,   1.6328974,  70.12957  , -72.92934  ,  31.001757 ,
#         10.664214 , -27.791878 ,  40.360817 , -38.84929  ,  53.04063  ,
#         40.892204 ,  70.12957  , -72.92934  ,  31.001757 ,  10.664214 ,
#         -3.6417851,  26.490097 ,  65.70101  , -11.596133 ,  -3.9064314,
#         28.728054 ,  17.346786 ,  70.98136  ,  64.034966 ,  51.924324 ,
#         -7.046082 ,  17.098356 ,  62.733433 , -14.4043865, -54.82337  ,
#         18.627234 ,  -5.561154 , -16.863125 ,  15.338919 , -64.55419  ,
#        -31.543785 , -69.55228  ,  57.936687 ,  25.930702 , -48.1334   ,
#        -58.89512  , -23.431276 , -34.782837 ,  47.92718  , -57.622963 ,
#        -36.69416  ,  40.360817 , -86.29295  ,  94.9668   ,  48.946434 ,
#         62.733433 , -47.230534 , -77.37954  , -56.420296 ], dtype=float32)

# %%
ranker.evaluate(X, y, qid, eval_at=10)
# Out:
# ndcg@10: 0.9998997466715455

# %%
## normalize predictions between 0 and 1

norm_pred = (pred - np.min(pred)) / (np.max(pred) - np.min(pred))
norm_pred
# Out:
# array([0.35862917, 0.        , 0.714703  , 0.3008581 , 0.17833164,
#        0.78095055, 0.51236326, 0.7174793 , 0.51236326, 0.8702342 ,
#        0.12280186, 0.6658052 , 0.55954874, 0.35862917, 0.35862917,
#        0.        , 0.714703  , 0.3008581 , 0.35862917, 0.        ,
#        0.714703  , 0.3008581 , 0.17833164, 0.78095055, 0.51236326,
#        0.7174793 , 0.67442477, 0.96841854, 0.67442477, 0.96841854,
#        0.35862917, 0.        , 0.714703  , 0.3008581 , 0.17833164,
#        0.78095055, 0.51236326, 0.7174793 , 0.51236326, 0.8702342 ,
#        0.12280186, 0.6658052 , 0.55954874, 0.35862917, 0.        ,
#        0.714703  , 0.3008581 , 0.17833164, 0.78095055, 0.51236326,
#        0.7174793 , 0.51236326, 0.8702342 , 0.12280186, 0.6658052 ,
#        0.55954874, 0.35862917, 0.714703  , 0.3008581 , 0.78095055,
#        0.7174793 , 0.8702342 , 0.12280186, 0.6658052 , 0.55954874,
#        0.4848049 , 0.6422334 , 0.84709656, 0.44324625, 0.48342222,
#        0.65392596, 0.5944628 , 0.8746846 , 0.838392  , 0.7751183 ,
#        0.46701866, 0.59316486, 0.831592  , 0.4285741 , 0.21739915,
#        0.6011527 , 0.47477686, 0.41572803, 0.5839724 , 0.16655904,
#        0.33902678, 0.14044581, 0.8065308 , 0.6393107 , 0.25235188,
#        0.1961257 , 0.3814118 , 0.3221039 , 0.7542346 , 0.20277227,
#        0.31211787, 0.714703  , 0.05298167, 1.        , 0.75955975,
#        0.831592  , 0.25706905, 0.09955112, 0.20905578], dtype=float32)

# %%
vector_df.sort_values('word2vec_fit', ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 27    28              Seeking Human Resources Opportunities
# 29    30              Seeking Human Resources Opportunities
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 67    68            Human Resources Specialist at Luxottica
# 100  101              Human Resources Generalist at Loparex
# 77    78             Human Resources Generalist at Schwan's
# 87    88                   Human Resources Management Major
# 59    60                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
#
#                                 location connection  word2vec_fit  bert_fit  \
# 98                Las Vegas, Nevada Area         48      0.920869  0.994894
# 27                     Chicago, Illinois        390      0.903864  0.996201
# 29                     Chicago, Illinois        390      0.903864  0.996201
# 72                   Houston, Texas Area          7      0.839220  0.975402
# 9              Greater Philadelphia Area      500+       0.808101  0.974998
# 39             Greater Philadelphia Area      500+       0.808101  0.974998
# 52             Greater Philadelphia Area      500+       0.808101  0.974998
# 61             Greater Philadelphia Area      500+       0.808101  0.974998
# 73                   Greater Boston Area         16      0.793325  0.991686
# 67            Greater New York City Area      500+       0.767376  0.974341
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962  0.982065
# 77           Amerika Birleşik Devletleri      500+       0.750962  0.982967
# 87                  Milpitas, California         18      0.747540  0.990193
# 59            Greater New York City Area          1      0.743151  0.987985
# 5             Greater New York City Area          1      0.743151  0.987985
#
#      tfidf_fit  glove_fit
# 98    0.625865   0.945992
# 27    0.646155   0.948254
# 29    0.646155   0.948254
# 72    0.552318   0.914078
# 9     0.447527   0.873041
# 39    0.447527   0.873041
# 52    0.447527   0.873041
# 61    0.447527   0.873041
# 73    0.351856   0.864729
# 67    0.170633   0.753141
# 100   0.172445   0.810235
# 77    0.172445   0.667156
# 87    0.183370   0.849824
# 59    0.261115   0.841785
# 5     0.261115   0.841785

# %%
## create a new dataframe to add ranknet scores

ranknet_df = vector_df.drop(['bert_fit', 'tfidf_fit', 'glove_fit'], axis=1)
ranknet_df['ranknet_fit'] = norm_pred
ranknet_df.sort_values('ranknet_fit', ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 27    28              Seeking Human Resources Opportunities
# 29    30              Seeking Human Resources Opportunities
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 67    68            Human Resources Specialist at Luxottica
# 73    74                       Human Resources Professional
# 77    78             Human Resources Generalist at Schwan's
# 100  101              Human Resources Generalist at Loparex
# 87    88                   Human Resources Management Major
# 23    24                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
#
#                                 location connection  word2vec_fit  ranknet_fit
# 98                Las Vegas, Nevada Area         48      0.920869     1.000000
# 27                     Chicago, Illinois        390      0.903864     0.968419
# 29                     Chicago, Illinois        390      0.903864     0.968419
# 72                   Houston, Texas Area          7      0.839220     0.874685
# 9              Greater Philadelphia Area      500+       0.808101     0.870234
# 39             Greater Philadelphia Area      500+       0.808101     0.870234
# 52             Greater Philadelphia Area      500+       0.808101     0.870234
# 61             Greater Philadelphia Area      500+       0.808101     0.870234
# 67            Greater New York City Area      500+       0.767376     0.847097
# 73                   Greater Boston Area         16      0.793325     0.838392
# 77           Amerika Birleşik Devletleri      500+       0.750962     0.831592
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962     0.831592
# 87                  Milpitas, California         18      0.747540     0.806531
# 23            Greater New York City Area          1      0.743151     0.780951
# 5             Greater New York City Area          1      0.743151     0.780951

# %% [markdown]
# The ranknet model performs very well in ranking candidates based on the word2vec fit score with the top candidates all being ranked the same as the original word2vec fit scores. Next let's create a function to star candidates and update our ranknet model based on the preferred candidates.

# %%
def star_candidate():
    star_cand = []
    x = ''

    while x != 'done':
        x = ''
        while not x.isdigit():
            x = input('Specify best candidate by id, when finished type "done": ')
            if x == 'done':
                break

        star_cand.append(x)

    star_cand = star_cand[:-1]
    
    return star_cand

# %%
star_cand = star_candidate()
# Out:
# Specify best candidate by id, when finished type "done": 15
# Specify best candidate by id, when finished type "done": 55
# Specify best candidate by id, when finished type "done": 78
# Specify best candidate by id, when finished type "done": 7
# Specify best candidate by id, when finished type "done": done

# %%
## subtract 1 from id to get index

star_cand = [int(i)-1 for i in star_cand]

# %%
star_cand
# Out:
# [14, 54, 77, 6]

# %%
## create a new column named star_score to update scores based on starred candidates

ranknet_df['star_score'] = ranknet_df['word2vec_fit']
ranknet_df.iloc[star_cand,[6]] = 1
ranknet_df.iloc[star_cand]
# Out:
#     id                                          job_title  \
# 14  15  2019 C.T. Bauer College of Business Graduate (...
# 54  55  SVP, CHRO, Marketing & Communications, CSR Off...
# 77  78             Human Resources Generalist at Schwan's
# 6    7  Student at Humber College and Aspiring Human R...
#
#                        location connection  word2vec_fit  ranknet_fit  \
# 14               Houston, Texas         85      0.388173     0.594211
# 54          Houston, Texas Area      500+       0.689503     0.595744
# 77  Amerika Birleşik Devletleri      500+       0.750962     0.804317
# 6                        Kanada         61      0.600016     0.546995
#
#     star_score
# 14         1.0
# 54         1.0
# 77         1.0
# 6          1.0

# %% [markdown]
# I created a new column called star_score and updated starred candidates scores to a 1 to allow the ranknet model to train on the updated score.

# %%
## create new target variable with updated starred candidates

y = np.array(ranknet_df['star_score'])

# %%
ranker = RankNetNN(input_size=X.shape[1], hidden_layer_sizes=(128, 64,), activation=('relu', 'relu',))
ranker.fit(X, y, qid, epochs=35)
# Out:
# Epoch 1/35
# 164/164 [==============================] - 1s 2ms/step - loss: 0.2435
# Epoch 2/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1747
# Epoch 3/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1714
# Epoch 4/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1685
# Epoch 5/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1684
# Epoch 6/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1666
# Epoch 7/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1647
# Epoch 8/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1626
# Epoch 9/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1660
# Epoch 10/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1637
# Epoch 11/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1633
# Epoch 12/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1628
# Epoch 13/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1606
# Epoch 14/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1617
# Epoch 15/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1629
# Epoch 16/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1609
# Epoch 17/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1615
# Epoch 18/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1617
# Epoch 19/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1599
# Epoch 20/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1598
# Epoch 21/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1598
# Epoch 22/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1612
# Epoch 23/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1604
# Epoch 24/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1602
# Epoch 25/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1606
# Epoch 26/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1600
# Epoch 27/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1576
# Epoch 28/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1595
# Epoch 29/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1602
# Epoch 30/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1588
# Epoch 31/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1609
# Epoch 32/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1602
# Epoch 33/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1577
# Epoch 34/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1594
# Epoch 35/35
# 164/164 [==============================] - 0s 2ms/step - loss: 0.1577
# ndcg: 0.9757146717839669

# %%
ranker.predict(X)
# Out:
# array([ 3.4388417e-01, -8.0197525e+01,  4.2854481e+00, -1.6946510e+01,
#        -4.0995636e+01,  5.0149212e+00,  2.0325110e+00,  3.1637673e+00,
#         2.0325110e+00,  6.4725933e+00, -5.3131245e+01,  3.5060163e+00,
#         1.1935713e+00,  3.4388417e-01,  3.4388417e-01, -8.0197525e+01,
#         4.2854481e+00, -1.6946510e+01,  3.4388417e-01, -8.0197525e+01,
#         4.2854481e+00, -1.6946510e+01, -4.0995636e+01,  5.0149212e+00,
#         2.0325110e+00,  3.1637673e+00,  3.2299366e+00,  7.4573684e+00,
#         3.2299366e+00,  7.4573684e+00,  3.4388417e-01, -8.0197525e+01,
#         4.2854481e+00, -1.6946510e+01, -4.0995636e+01,  5.0149212e+00,
#         2.0325110e+00,  3.1637673e+00,  2.0325110e+00,  6.4725933e+00,
#        -5.3131245e+01,  3.5060163e+00,  1.1935713e+00,  3.4388417e-01,
#        -8.0197525e+01,  4.2854481e+00, -1.6946510e+01, -4.0995636e+01,
#         5.0149212e+00,  2.0325110e+00,  3.1637673e+00,  2.0325110e+00,
#         6.4725933e+00, -5.3131245e+01,  3.5060163e+00,  1.1935713e+00,
#         3.4388417e-01,  4.2854481e+00, -1.6946510e+01,  5.0149212e+00,
#         3.1637673e+00,  6.4725933e+00, -5.3131245e+01,  3.5060163e+00,
#         1.1935713e+00,  7.9467607e-01,  2.4800291e+00,  5.5765343e+00,
#        -1.6484793e+00,  2.9435086e-01,  2.0557382e+00,  2.4100561e+00,
#         6.6095743e+00,  5.7822676e+00,  4.6452909e+00,  6.8202853e-01,
#         2.1116228e+00,  6.8085108e+00, -2.0359159e-02, -3.0324547e+01,
#         2.0536575e+00,  3.5278130e-01, -1.3499612e+00,  1.8175378e+00,
#        -4.6330566e+01, -6.1478333e+00, -4.9466457e+01,  5.3091307e+00,
#         2.0242360e+00, -2.0664106e+01, -3.7716679e+01, -7.8305423e-01,
#        -9.4911394e+00,  4.5291281e+00, -3.3681755e+01, -1.1657148e+01,
#         4.2854481e+00, -6.5369934e+01,  7.8546429e+00,  4.5508642e+00,
#         6.8085108e+00, -2.2560337e+01, -5.7594429e+01, -2.6631561e+01],
#       dtype=float32)

# %%
ranker.evaluate(X, y, qid, eval_at=10)
# Out:
# ndcg@10: 0.9011320170117706

# %%
norm_pred = (ranker.predict(X) - np.min(ranker.predict(X))) / (np.max(ranker.predict(X)) - np.min(ranker.predict(X)))
ranknet_df['ranknet_fit'] = norm_pred

# %%
ranknet_df.sort_values('star_score', ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 54    55  SVP, CHRO, Marketing & Communications, CSR Off...
# 6      7  Student at Humber College and Aspiring Human R...
# 77    78             Human Resources Generalist at Schwan's
# 14    15  2019 C.T. Bauer College of Business Graduate (...
# 98    99                   Seeking Human Resources Position
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 67    68            Human Resources Specialist at Luxottica
# 100  101              Human Resources Generalist at Loparex
#
#                                 location connection  word2vec_fit  \
# 54                   Houston, Texas Area      500+       0.689503
# 6                                 Kanada         61      0.600016
# 77           Amerika Birleşik Devletleri      500+       0.750962
# 14                        Houston, Texas         85      0.388173
# 98                Las Vegas, Nevada Area         48      0.920869
# 29                     Chicago, Illinois        390      0.903864
# 27                     Chicago, Illinois        390      0.903864
# 72                   Houston, Texas Area          7      0.839220
# 61             Greater Philadelphia Area      500+       0.808101
# 39             Greater Philadelphia Area      500+       0.808101
# 52             Greater Philadelphia Area      500+       0.808101
# 9              Greater Philadelphia Area      500+       0.808101
# 73                   Greater Boston Area         16      0.793325
# 67            Greater New York City Area      500+       0.767376
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962
#
#      ranknet_fit  star_score
# 54      0.950613    1.000000
# 6       0.933879    1.000000
# 77      0.988119    1.000000
# 14      0.914701    1.000000
# 98      1.000000    0.920869
# 29      0.995488    0.903864
# 27      0.995488    0.903864
# 72      0.985860    0.839220
# 61      0.984304    0.808101
# 39      0.984304    0.808101
# 52      0.984304    0.808101
# 9       0.984304    0.808101
# 73      0.976464    0.793325
# 67      0.974128    0.767376
# 100     0.988119    0.750962

# %%
ranknet_df.sort_values('ranknet_fit', ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 100  101              Human Resources Generalist at Loparex
# 77    78             Human Resources Generalist at Schwan's
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 67    68            Human Resources Specialist at Luxottica
# 87    88                   Human Resources Management Major
# 48    49                Aspiring Human Resources Specialist
# 35    36                Aspiring Human Resources Specialist
#
#                                 location connection  word2vec_fit  \
# 98                Las Vegas, Nevada Area         48      0.920869
# 29                     Chicago, Illinois        390      0.903864
# 27                     Chicago, Illinois        390      0.903864
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962
# 77           Amerika Birleşik Devletleri      500+       0.750962
# 72                   Houston, Texas Area          7      0.839220
# 52             Greater Philadelphia Area      500+       0.808101
# 61             Greater Philadelphia Area      500+       0.808101
# 39             Greater Philadelphia Area      500+       0.808101
# 9              Greater Philadelphia Area      500+       0.808101
# 73                   Greater Boston Area         16      0.793325
# 67            Greater New York City Area      500+       0.767376
# 87                  Milpitas, California         18      0.747540
# 48            Greater New York City Area          1      0.743151
# 35            Greater New York City Area          1      0.743151
#
#      ranknet_fit  star_score
# 98      1.000000    0.920869
# 29      0.995488    0.903864
# 27      0.995488    0.903864
# 100     0.988119    0.750962
# 77      0.988119    1.000000
# 72      0.985860    0.839220
# 52      0.984304    0.808101
# 61      0.984304    0.808101
# 39      0.984304    0.808101
# 9       0.984304    0.808101
# 73      0.976464    0.793325
# 67      0.974128    0.767376
# 87      0.971091    0.747540
# 48      0.967750    0.743151
# 35      0.967750    0.743151

# %%
## dataframe without the starred candidates 

ranknet_df.drop(star_cand).sort_values('ranknet_fit', ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 100  101              Human Resources Generalist at Loparex
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 67    68            Human Resources Specialist at Luxottica
# 87    88                   Human Resources Management Major
# 48    49                Aspiring Human Resources Specialist
# 35    36                Aspiring Human Resources Specialist
# 23    24                Aspiring Human Resources Specialist
#
#                                 location connection  word2vec_fit  \
# 98                Las Vegas, Nevada Area         48      0.920869
# 29                     Chicago, Illinois        390      0.903864
# 27                     Chicago, Illinois        390      0.903864
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962
# 72                   Houston, Texas Area          7      0.839220
# 52             Greater Philadelphia Area      500+       0.808101
# 61             Greater Philadelphia Area      500+       0.808101
# 39             Greater Philadelphia Area      500+       0.808101
# 9              Greater Philadelphia Area      500+       0.808101
# 73                   Greater Boston Area         16      0.793325
# 67            Greater New York City Area      500+       0.767376
# 87                  Milpitas, California         18      0.747540
# 48            Greater New York City Area          1      0.743151
# 35            Greater New York City Area          1      0.743151
# 23            Greater New York City Area          1      0.743151
#
#      ranknet_fit  star_score
# 98      1.000000    0.920869
# 29      0.995488    0.903864
# 27      0.995488    0.903864
# 100     0.988119    0.750962
# 72      0.985860    0.839220
# 52      0.984304    0.808101
# 61      0.984304    0.808101
# 39      0.984304    0.808101
# 9       0.984304    0.808101
# 73      0.976464    0.793325
# 67      0.974128    0.767376
# 87      0.971091    0.747540
# 48      0.967750    0.743151
# 35      0.967750    0.743151
# 23      0.967750    0.743151

# %% [markdown]
# The ranknet model was able to update its scores based on the starred candidates and return an updated list that takes the starred candidates into account. Let's see if the ranknet model performs just as well with a different query.

# %% [markdown]
# ## RankNet Model with a Different Query

# %% [markdown]
# I'll be using the query 'aspiring human resources' to rank the potential job candidates. I will be using Word2Vec vectors for this because it had the best performing word embeddings for the previous query.

# %%
list_2 = word2vec_list(df, 'aspiring human resources')
list_2
# Out:
# [['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['experienced',
#   'retail',
#   'manager',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['human', 'resources', 'staffing', 'recruiting', 'professional'],
#  ['human', 'resources', 'specialist'],
#  ['director', 'human', 'resources', 'north', 'america', 'groupe'],
#  ['retired',
#   'army',
#   'national',
#   'guard',
#   'recruiter',
#   'office',
#   'manager',
#   'seeking',
#   'position',
#   'human',
#   'resources'],
#  ['human', 'resources', 'generalist', 'inc'],
#  ['business',
#   'management',
#   'major',
#   'aspiring',
#   'human',
#   'resources',
#   'manager'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'seeking',
#   'internship',
#   'human',
#   'resources'],
#  ['human', 'resources', 'professional'],
#  ['staffing',
#   'seeking',
#   'human',
#   'resources',
#   'payroll',
#   'administrative',
#   'professionals'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'passionate',
#   'helping',
#   'create',
#   'inclusive',
#   'engaging',
#   'work',
#   'environment'],
#  ['human',
#   'resources',
#   'conflict',
#   'management',
#   'policies',
#   'procedures',
#   'talent',
#   'management',
#   'benefits',
#   'compensation'],
#  ['human', 'resources', 'generalist'],
#  ['liberal', 'arts', 'major', 'aspiring', 'human', 'resources', 'analyst'],
#  ['junior', 'mes', 'engineer', 'information', 'systems'],
#  ['senior',
#   'human',
#   'resources',
#   'business',
#   'partner',
#   'heil',
#   'environmental'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'energetic',
#   'team',
#   'focused',
#   'leader'],
#  ['human', 'resources', 'manager', 'shine', 'north', 'america'],
#  ['human', 'resources', 'professional', 'world', 'leader', 'gis', 'software'],
#  ['rrp',
#   'brand',
#   'portfolio',
#   'executive',
#   'japan',
#   'tobacco',
#   'international'],
#  ['information',
#   'systems',
#   'specialist',
#   'programmer',
#   'love',
#   'data',
#   'organization'],
#  ['bachelor', 'science', 'biology', 'victoria', 'university', 'wellington'],
#  ['human', 'resources', 'management', 'major'],
#  ['director', 'human', 'resources', 'ey'],
#  ['undergraduate', 'research', 'assistant', 'lab'],
#  ['lead', 'official', 'western', 'illinois', 'university'],
#  ['seeking',
#   'employment',
#   'opportunities',
#   'within',
#   'customer',
#   'service',
#   'patient',
#   'care'],
#  ['admissions',
#   'representative',
#   'community',
#   'medical',
#   'center',
#   'long',
#   'beach'],
#  ['seeking',
#   'human',
#   'resources',
#   'opportunities',
#   'open',
#   'travel',
#   'relocation'],
#  ['student', 'state', 'university'],
#  ['student',
#   'indiana',
#   'university',
#   'business',
#   'management',
#   'retail',
#   'manager',
#   'hardware',
#   'paint'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['student'],
#  ['seeking', 'human', 'resources', 'position'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'graduating',
#   'may',
#   'seeking',
#   'entry',
#   'level',
#   'human',
#   'resources',
#   'position',
#   'st',
#   'louis'],
#  ['human', 'resources', 'generalist'],
#  ['business', 'intelligence', 'analytics', 'travelers'],
#  ['always', 'set', 'success'],
#  ['director', 'administration', 'excellence', 'logging'],
#  ['aspiring', 'human', 'resources']]

# %%
## get vectors with the new query

vectorizer = Vectorizer()
vectorizer.word2vec(list_2, pretrained_vectors_path= './GoogleNews-vectors-negative300.bin')
word2vec_vectors = vectorizer.vectors

# %%
## append vector distance of job description and query to dataframe

df_2 = df.drop('fit', axis=1)

scores = []
for num in range(len(job_desc_list) - 1):
    scores.append(1 - spatial.distance.cosine(word2vec_vectors[num], word2vec_vectors[-1]))
    
df_2['word2vec_fit'] = scores
df_2.sort_values('word2vec_fit', ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 45  46              Aspiring Human Resources Professional
# 2    3              Aspiring Human Resources Professional
# 32  33              Aspiring Human Resources Professional
# 20  21              Aspiring Human Resources Professional
# 16  17              Aspiring Human Resources Professional
# 57  58              Aspiring Human Resources Professional
# 96  97              Aspiring Human Resources Professional
# 35  36                Aspiring Human Resources Specialist
# 5    6                Aspiring Human Resources Specialist
# 48  49                Aspiring Human Resources Specialist
# 59  60                Aspiring Human Resources Specialist
# 23  24                Aspiring Human Resources Specialist
# 72  73  Aspiring Human Resources Manager, seeking inte...
# 73  74                       Human Resources Professional
# 36  37  Student at Humber College and Aspiring Human R...
#
#                                location connection  word2vec_fit
# 45  Raleigh-Durham, North Carolina Area         44      0.945019
# 2   Raleigh-Durham, North Carolina Area         44      0.945019
# 32  Raleigh-Durham, North Carolina Area         44      0.945019
# 20  Raleigh-Durham, North Carolina Area         44      0.945019
# 16  Raleigh-Durham, North Carolina Area         44      0.945019
# 57  Raleigh-Durham, North Carolina Area         44      0.945019
# 96                 Kokomo, Indiana Area         71      0.945019
# 35           Greater New York City Area          1      0.905420
# 5            Greater New York City Area          1      0.905420
# 48           Greater New York City Area          1      0.905420
# 59           Greater New York City Area          1      0.905420
# 23           Greater New York City Area          1      0.905420
# 72                  Houston, Texas Area          7      0.872285
# 73                  Greater Boston Area         16      0.865165
# 36                               Kanada         61      0.815372

# %%
X = pd.DataFrame(word2vec_vectors)
y = np.array(df_2['word2vec_fit'])

X.drop([104], inplace=True)
X['qid'] = 1
qid = np.array(X['qid'])
X.drop('qid', axis=1, inplace=True)
X = X.to_numpy()

# %%
ranker = RankNetNN(input_size=X.shape[1], hidden_layer_sizes=(128, 64,), activation=('relu', 'relu',))
ranker.fit(X, y, qid, epochs=35)
# Out:
# Epoch 1/35
# 163/163 [==============================] - 1s 1ms/step - loss: 0.1540
# Epoch 2/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0416
# Epoch 3/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 4/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0230
# Epoch 5/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0182
# Epoch 6/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0196
# Epoch 7/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0115
# Epoch 8/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0099
# Epoch 9/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0153
# Epoch 10/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0090
# Epoch 11/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0074
# Epoch 12/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0156
# Epoch 13/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 14/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 15/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0115
# Epoch 16/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 17/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0117
# Epoch 18/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0059
# Epoch 19/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 20/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 21/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0078
# Epoch 22/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0086
# Epoch 23/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 24/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 25/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0064
# Epoch 26/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0033
# Epoch 27/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 28/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0045
# Epoch 29/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 30/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0189
# Epoch 31/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 32/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0052
# Epoch 33/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 34/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 35/35
# 163/163 [==============================] - 0s 1ms/step - loss: 0.0030
# ndcg: 0.9999957101147271

# %%
pred = (ranker.predict(X) - np.min(ranker.predict(X))) / (np.max(ranker.predict(X)) - np.min(ranker.predict(X)))
df_2['ranknet_fit'] = pred
df_2.sort_values('ranknet_fit', ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 45  46              Aspiring Human Resources Professional
# 2    3              Aspiring Human Resources Professional
# 32  33              Aspiring Human Resources Professional
# 20  21              Aspiring Human Resources Professional
# 16  17              Aspiring Human Resources Professional
# 57  58              Aspiring Human Resources Professional
# 96  97              Aspiring Human Resources Professional
# 35  36                Aspiring Human Resources Specialist
# 5    6                Aspiring Human Resources Specialist
# 48  49                Aspiring Human Resources Specialist
# 59  60                Aspiring Human Resources Specialist
# 23  24                Aspiring Human Resources Specialist
# 72  73  Aspiring Human Resources Manager, seeking inte...
# 73  74                       Human Resources Professional
# 36  37  Student at Humber College and Aspiring Human R...
#
#                                location connection  word2vec_fit  ranknet_fit  \
# 45  Raleigh-Durham, North Carolina Area         44      0.945019     1.000000
# 2   Raleigh-Durham, North Carolina Area         44      0.945019     1.000000
# 32  Raleigh-Durham, North Carolina Area         44      0.945019     1.000000
# 20  Raleigh-Durham, North Carolina Area         44      0.945019     1.000000
# 16  Raleigh-Durham, North Carolina Area         44      0.945019     1.000000
# 57  Raleigh-Durham, North Carolina Area         44      0.945019     1.000000
# 96                 Kokomo, Indiana Area         71      0.945019     1.000000
# 35           Greater New York City Area          1      0.905420     0.883866
# 5            Greater New York City Area          1      0.905420     0.883866
# 48           Greater New York City Area          1      0.905420     0.883866
# 59           Greater New York City Area          1      0.905420     0.883866
# 23           Greater New York City Area          1      0.905420     0.883866
# 72                  Houston, Texas Area          7      0.872285     0.853892
# 73                  Greater Boston Area         16      0.865165     0.832696
# 36                               Kanada         61      0.815372     0.813642
#
#     star_score
# 45    0.945019
# 2     0.945019
# 32    0.945019
# 20    0.945019
# 16    0.945019
# 57    1.000000
# 96    0.945019
# 35    0.905420
# 5     0.905420
# 48    0.905420
# 59    0.905420
# 23    0.905420
# 72    0.872285
# 73    0.865165
# 36    0.815372

# %%
star_cand = star_candidate()
# Out:
# Specify best candidate by id, when finished type "done": 6
# Specify best candidate by id, when finished type "done": 10
# Specify best candidate by id, when finished type "done": 25
# Specify best candidate by id, when finished type "done": 39
# Specify best candidate by id, when finished type "done": 52
# Specify best candidate by id, when finished type "done": 74
# Specify best candidate by id, when finished type "done": done

# %%
## subtract 1 from id to get index
star_cand = [int(i)-1 for i in star_cand]

df_2['star_score'] = df_2['word2vec_fit']
df_2.iloc[star_cand,[6]] = 1
df_2.iloc[star_cand]
# Out:
#     id                                          job_title  \
# 5    6                Aspiring Human Resources Specialist
# 9   10  Seeking Human Resources HRIS and Generalist Po...
# 24  25  Student at Humber College and Aspiring Human R...
# 38  39  Student at Humber College and Aspiring Human R...
# 51  52  Student at Humber College and Aspiring Human R...
# 73  74                       Human Resources Professional
#
#                       location connection  word2vec_fit  ranknet_fit  \
# 5   Greater New York City Area          1      0.905420     0.883866
# 9    Greater Philadelphia Area      500+       0.693193     0.603403
# 24                      Kanada         61      0.815372     0.813642
# 38                      Kanada         61      0.815372     0.813642
# 51                      Kanada         61      0.815372     0.813642
# 73         Greater Boston Area         16      0.865165     0.832696
#
#     star_score
# 5          1.0
# 9          1.0
# 24         1.0
# 38         1.0
# 51         1.0
# 73         1.0

# %%
y = np.array(df_2['star_score'])

ranker = RankNetNN(input_size=X.shape[1], hidden_layer_sizes=(128, 64,), activation=('relu', 'relu',))
ranker.fit(X, y, qid, epochs=35)
# Out:
# Epoch 1/35
# 164/164 [==============================] - 1s 1ms/step - loss: 0.1862
# Epoch 2/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0861
# Epoch 3/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0763
# Epoch 4/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0712
# Epoch 5/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0666
# Epoch 6/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0658
# Epoch 7/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0671
# Epoch 8/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0617
# Epoch 9/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0604
# Epoch 10/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0627
# Epoch 11/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0602
# Epoch 12/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0611
# Epoch 13/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0609
# Epoch 14/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0583
# Epoch 15/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0669
# Epoch 16/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0599
# Epoch 17/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0593
# Epoch 18/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0625
# Epoch 19/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0656
# Epoch 20/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0617
# Epoch 21/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0570
# Epoch 22/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0551
# Epoch 23/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0573
# Epoch 24/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0558
# Epoch 25/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0571
# Epoch 26/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0595
# Epoch 27/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0626
# Epoch 28/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0578
# Epoch 29/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0601
# Epoch 30/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0568
# Epoch 31/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0561
# Epoch 32/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0576
# Epoch 33/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0560
# Epoch 34/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0553
# Epoch 35/35
# 164/164 [==============================] - 0s 1ms/step - loss: 0.0538
# ndcg: 0.9911428184991445

# %%
pred = (ranker.predict(X) - np.min(ranker.predict(X))) / (np.max(ranker.predict(X)) - np.min(ranker.predict(X)))
df_2['ranknet_fit'] = pred
df_2.sort_values('ranknet_fit', ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 73  74                       Human Resources Professional
# 16  17              Aspiring Human Resources Professional
# 57  58              Aspiring Human Resources Professional
# 20  21              Aspiring Human Resources Professional
# 45  46              Aspiring Human Resources Professional
# 96  97              Aspiring Human Resources Professional
# 32  33              Aspiring Human Resources Professional
# 2    3              Aspiring Human Resources Professional
# 36  37  Student at Humber College and Aspiring Human R...
# 6    7  Student at Humber College and Aspiring Human R...
# 51  52  Student at Humber College and Aspiring Human R...
# 49  50  Student at Humber College and Aspiring Human R...
# 8    9  Student at Humber College and Aspiring Human R...
# 38  39  Student at Humber College and Aspiring Human R...
# 24  25  Student at Humber College and Aspiring Human R...
#
#                                location connection  word2vec_fit  ranknet_fit  \
# 73                  Greater Boston Area         16      0.865165     1.000000
# 16  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 57  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 20  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 45  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 96                 Kokomo, Indiana Area         71      0.945019     0.985955
# 32  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 2   Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 36                               Kanada         61      0.815372     0.982069
# 6                                Kanada         61      0.815372     0.982069
# 51                               Kanada         61      0.815372     0.982069
# 49                               Kanada         61      0.815372     0.982069
# 8                                Kanada         61      0.815372     0.982069
# 38                               Kanada         61      0.815372     0.982069
# 24                               Kanada         61      0.815372     0.982069
#
#     star_score
# 73    1.000000
# 16    0.945019
# 57    0.945019
# 20    0.945019
# 45    0.945019
# 96    0.945019
# 32    0.945019
# 2     0.945019
# 36    0.815372
# 6     0.815372
# 51    1.000000
# 49    0.815372
# 8     0.815372
# 38    1.000000
# 24    1.000000

# %%
## dataframe ranked by word2vec score for comparison

df_2.sort_values('word2vec_fit', ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 45  46              Aspiring Human Resources Professional
# 2    3              Aspiring Human Resources Professional
# 32  33              Aspiring Human Resources Professional
# 20  21              Aspiring Human Resources Professional
# 16  17              Aspiring Human Resources Professional
# 57  58              Aspiring Human Resources Professional
# 96  97              Aspiring Human Resources Professional
# 35  36                Aspiring Human Resources Specialist
# 5    6                Aspiring Human Resources Specialist
# 48  49                Aspiring Human Resources Specialist
# 59  60                Aspiring Human Resources Specialist
# 23  24                Aspiring Human Resources Specialist
# 72  73  Aspiring Human Resources Manager, seeking inte...
# 73  74                       Human Resources Professional
# 36  37  Student at Humber College and Aspiring Human R...
#
#                                location connection  word2vec_fit  ranknet_fit  \
# 45  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 2   Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 32  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 20  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 16  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 57  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 96                 Kokomo, Indiana Area         71      0.945019     0.985955
# 35           Greater New York City Area          1      0.905420     0.980887
# 5            Greater New York City Area          1      0.905420     0.980887
# 48           Greater New York City Area          1      0.905420     0.980887
# 59           Greater New York City Area          1      0.905420     0.980887
# 23           Greater New York City Area          1      0.905420     0.980887
# 72                  Houston, Texas Area          7      0.872285     0.973870
# 73                  Greater Boston Area         16      0.865165     1.000000
# 36                               Kanada         61      0.815372     0.982069
#
#     star_score
# 45    0.945019
# 2     0.945019
# 32    0.945019
# 20    0.945019
# 16    0.945019
# 57    0.945019
# 96    0.945019
# 35    0.905420
# 5     1.000000
# 48    0.905420
# 59    0.905420
# 23    0.905420
# 72    0.872285
# 73    1.000000
# 36    0.815372

# %%
## dataframe without the starred candidates 

df_2.drop(star_cand).sort_values('ranknet_fit', ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 45  46              Aspiring Human Resources Professional
# 96  97              Aspiring Human Resources Professional
# 32  33              Aspiring Human Resources Professional
# 16  17              Aspiring Human Resources Professional
# 20  21              Aspiring Human Resources Professional
# 57  58              Aspiring Human Resources Professional
# 2    3              Aspiring Human Resources Professional
# 6    7  Student at Humber College and Aspiring Human R...
# 49  50  Student at Humber College and Aspiring Human R...
# 8    9  Student at Humber College and Aspiring Human R...
# 36  37  Student at Humber College and Aspiring Human R...
# 48  49                Aspiring Human Resources Specialist
# 23  24                Aspiring Human Resources Specialist
# 35  36                Aspiring Human Resources Specialist
# 59  60                Aspiring Human Resources Specialist
#
#                                location connection  word2vec_fit  ranknet_fit  \
# 45  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 96                 Kokomo, Indiana Area         71      0.945019     0.985955
# 32  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 16  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 20  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 57  Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 2   Raleigh-Durham, North Carolina Area         44      0.945019     0.985955
# 6                                Kanada         61      0.815372     0.982069
# 49                               Kanada         61      0.815372     0.982069
# 8                                Kanada         61      0.815372     0.982069
# 36                               Kanada         61      0.815372     0.982069
# 48           Greater New York City Area          1      0.905420     0.980887
# 23           Greater New York City Area          1      0.905420     0.980887
# 35           Greater New York City Area          1      0.905420     0.980887
# 59           Greater New York City Area          1      0.905420     0.980887
#
#     star_score
# 45    0.945019
# 96    0.945019
# 32    0.945019
# 16    0.945019
# 20    0.945019
# 57    0.945019
# 2     0.945019
# 6     0.815372
# 49    0.815372
# 8     0.815372
# 36    0.815372
# 48    0.905420
# 23    0.905420
# 35    0.905420
# 59    0.905420

# %% [markdown]
# After starring the candidates, we can see that the ranknet model learned from the starred candidates like our previous query. The learning after starring is more apparent here because we can see that the "Student at Humber College..." rises in rank with our ranknet model when compared to just ranking with the word2vec fit score. The model is able to learn to rank  more easily when you star candidates that were similar to the query to begin with.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The learning to rank model after ranking with starred candidates had a NDCG score of 0.975 for the first query and a NDCG score of 0.991 for the second query. The model is able to learn to rank more accurately when you star candidates that were similar to the query to begin with based on the higher NDCG score of the second query. With such a high NDCG score, I am confident in the model to correctly rerank potential candidates based on preferred candidates.

# %% [markdown]
# # Appendix

# %% [markdown]
# # Different RankNet Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class RankNet(nn.Module):
    
    def __init__(self, num_feature):
        super(RankNet, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(num_feature, 512),         # Linear layer - linear projection
            nn.Dropout(0.5),                     # Regularization - Drops some of the neurons in a random fashion
            nn.LeakyReLU(0.2, inplace=True),     # Activation function - swap dropout and relu
            nn.Linear(512, 256),
            nn.Dropout(0.5),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid()                         # Applies a function on the output and brings the output bw 0 and 1. Softmax is replacement
        )
        self.output_sig = nn.Sigmoid()

    def forward(self, input_1, input_2):
        s1 = self.model(input_1)
        s2 = self.model(input_2)
        out = self.output_sig(s1-s2)
        return out
    
    def predict(self, input_):
        s = self.model(input_)
        return s

# %%
## clean up data and make a list that can be run through the Word2Vec model

def ranknet_list(desc_list):
    clean_list = []

    for num in range(len(desc_list)):
        desc = desc_list[num]
        ## remove punctuation from job description    
        for symbol in list(string.punctuation):
            desc = desc.replace(symbol, ' ')

        ## write out acronyms for human resource positions
        desc = nltk.word_tokenize(desc)
        for word in range(len(desc)):
            if desc[word] == 'HR':
                desc[word] = 'Human Resources'
            elif desc[word] == 'CHRO':
                desc[word] = 'Chief Human Resources Officer'
            elif desc[word] == 'GPHR':
                desc[word] = 'General Professional Human Resources'
            elif desc[word] == 'SPHR':
                desc[word] = 'Senior Professional Human Resources'

            ## remove words that are not in pretrained vectors
            ## most of these words are the names of colleges
            elif desc[word] in ['EPIK', 'Celal', 'Bayar', 'Humber', 'ENGIE', 'Buckhead', 'Luxottica', 'Beneteau', 'ScottMadden', 
                                'Nortia', 'Schwan', 'Endemol', 'JTI', 'Styczynski', 'Westfield', 'Kokomo', 'Delphi', 'Loparex']:
                desc[word] = ''
            desc[word] = desc[word].lower()

        ## remove stopwords
        desc = [token for token in desc if token not in stopwords.words('english')]
        desc = [token for token in desc if not token.isdigit()]

        desc = ' '.join(desc)
        desc = nltk.word_tokenize(desc)

        clean_list.append(desc)
    
    return clean_list

# %%
random_row_1 = ranknet_df.sample(n = 5000, replace = True)
random_row_2 = ranknet_df.sample(n = 5000, replace = True)
job_title_list_ranknet1 = ranknet_list(list(random_row_1['job_title']))
job_title_list_ranknet2 = ranknet_list(list(random_row_2['job_title']))

# %%
vectorizer = Vectorizer()
vectorizer.word2vec(job_title_list_ranknet1, pretrained_vectors_path= './GoogleNews-vectors-negative300.bin')
doc1 = np.array(vectorizer.vectors)

vectorizer = Vectorizer()
vectorizer.word2vec(job_title_list_ranknet2, pretrained_vectors_path= './GoogleNews-vectors-negative300.bin')
doc2 = np.array(vectorizer.vectors)

doc1 = torch.from_numpy(doc1).float()
doc2 = torch.from_numpy(doc2).float()

# %%
y_1 = list(random_row_1['star_score'])
y_2 = list(random_row_2['star_score'])
y = torch.tensor([1.0 if y1_i>y2_i else 0.5 if y1_i==y2_i else 0.0 for y1_i, y2_i in zip(y_1, y_2)]).float()

y = y.unsqueeze(1)

# %%
rank_model = RankNet(num_feature = 300)
# optimizer = torch.optim.Adam(rank_model.parameters())         
optimizer = torch.optim.SGD(rank_model.parameters(), lr = 0.01, momentum = 0.9)         # experiment with optimizer
loss_fun = torch.nn.BCELoss()

# %%
epoch = 2000
losses = []

for i in range(epoch):
    rank_model.zero_grad()
    y_pred = rank_model(doc1, doc2)
    loss = loss_fun(y_pred,y)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    #print(y1, y2, y, y_pred)
    
    if i % 100 == 0:
        print('Epoch{}, loss : {}'.format(i, loss.item()))
# Out:
# Epoch0, loss : 0.6930458545684814
# Epoch100, loss : 0.6887785196304321
# Epoch200, loss : 0.6791598200798035
# Epoch300, loss : 0.6494277119636536
# Epoch400, loss : 0.5845950841903687
# Epoch500, loss : 0.5449822545051575
# Epoch600, loss : 0.5309036374092102
# Epoch700, loss : 0.5275877118110657
# Epoch800, loss : 0.5241197347640991
# Epoch900, loss : 0.522300124168396
# Epoch1000, loss : 0.5205228328704834
# Epoch1100, loss : 0.5205462574958801
# Epoch1200, loss : 0.5199341773986816
# Epoch1300, loss : 0.5188631415367126
# Epoch1400, loss : 0.5178435444831848
# Epoch1500, loss : 0.5178009867668152
# Epoch1600, loss : 0.5164840221405029
# Epoch1700, loss : 0.5165194869041443
# Epoch1800, loss : 0.5173816680908203
# Epoch1900, loss : 0.5155891180038452

# %%
pred = rank_model.predict(torch.from_numpy(X))
ranknet_df['ranknet_fit'] = norm_pred

# %%
ranknet_df.sort_values('ranknet_fit', ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 100  101              Human Resources Generalist at Loparex
# 77    78             Human Resources Generalist at Schwan's
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 67    68            Human Resources Specialist at Luxottica
# 87    88                   Human Resources Management Major
# 5      6                Aspiring Human Resources Specialist
# 48    49                Aspiring Human Resources Specialist
#
#                                 location connection  word2vec_fit  \
# 98                Las Vegas, Nevada Area         48      0.920869
# 29                     Chicago, Illinois        390      0.903864
# 27                     Chicago, Illinois        390      0.903864
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962
# 77           Amerika Birleşik Devletleri      500+       0.750962
# 72                   Houston, Texas Area          7      0.839220
# 9              Greater Philadelphia Area      500+       0.808101
# 61             Greater Philadelphia Area      500+       0.808101
# 39             Greater Philadelphia Area      500+       0.808101
# 52             Greater Philadelphia Area      500+       0.808101
# 73                   Greater Boston Area         16      0.793325
# 67            Greater New York City Area      500+       0.767376
# 87                  Milpitas, California         18      0.747540
# 5             Greater New York City Area          1      0.743151
# 48            Greater New York City Area          1      0.743151
#
#      ranknet_fit  star_score
# 98      1.000000    0.920869
# 29      0.995216    0.903864
# 27      0.995216    0.903864
# 100     0.993609    0.750962
# 77      0.993609    1.000000
# 72      0.989833    0.839220
# 9       0.987375    0.808101
# 61      0.987375    0.808101
# 39      0.987375    0.808101
# 52      0.987375    0.808101
# 73      0.983743    0.793325
# 67      0.982229    0.767376
# 87      0.978794    0.747540
# 5       0.974604    0.743151
# 48      0.974604    0.743151
