# %%
## import necessary libraries

import pandas as pd
import nltk
import string
import gensim
import itertools
import numpy as np
from scipy import spatial
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sent2vec.vectorizer import Vectorizer
from sent2vec.splitter import Splitter
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('./potential-talents - Aspiring human resources - seeking human resources.csv')
df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN

# %% [markdown]
# ## Word2Vec

# %%
job_desc_list = []

for num in range(len(df)):
    desc = df.iloc[num]['job_title']
    ## remove punctuation from job description    
    for symbol in list(string.punctuation):
        desc = desc.replace(symbol, ' ')
    
    ## write out acronyms for human resource positions
    desc = nltk.word_tokenize(desc)
    for word in range(len(desc)):
        if desc[word] == 'HR':
            desc[word] = 'Human Resources'
        elif desc[word] == 'CHRO':
            desc[word] = 'Chief Human Resources Officer'
        elif desc[word] == 'GPHR':
            desc[word] = 'General Professional Human Resources'
        elif desc[word] == 'SPHR':
            desc[word] = 'Senior Professional Human Resources'
            
        ## remove words that are not in pretrained vectors
        ## most of these words are the names of colleges
        elif desc[word] in ['EPIK', 'Celal', 'Bayar', 'Humber', 'ENGIE', 'Buckhead', 'Luxottica', 'Beneteau', 'ScottMadden', 
                            'Nortia', 'Schwan', 'Endemol', 'JTI', 'Styczynski', 'Westfield', 'Kokomo', 'Delphi', 'Loparex']:
            desc[word] = ''
        desc[word] = desc[word].lower()

    ## remove stopwords
    desc = [token for token in desc if token not in stopwords.words('english')]
    desc = [token for token in desc if not token.isdigit()]
    
    desc = ' '.join(desc)
    desc = nltk.word_tokenize(desc)
    
    job_desc_list.append(desc)

# %%
job_desc_list.append(['seeking', 'human', 'resources'])

# %%
job_desc_list
# Out:
# [['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['aspiring',
#   'human',
#   'resources',
#   'management',
#   'student',
#   'seeking',
#   'internship'],
#  ['seeking', 'human', 'resources', 'opportunities'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['native', 'english', 'teacher', 'english', 'program', 'korea'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['advisory', 'board', 'member', 'university'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['student', 'college', 'aspiring', 'human', 'resources', 'generalist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['c',
#   'bauer',
#   'college',
#   'business',
#   'graduate',
#   'magna',
#   'cum',
#   'laude',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['people', 'development', 'coordinator', 'ryan'],
#  ['aspiring', 'human', 'resources', 'specialist'],
#  ['human', 'resources', 'senior', 'specialist'],
#  ['seeking', 'human', 'resources', 'hris', 'generalist', 'positions'],
#  ['student', 'chapman', 'university'],
#  ['svp',
#   'chief',
#   'human',
#   'resources',
#   'officer',
#   'marketing',
#   'communications',
#   'csr',
#   'officer',
#   'houston',
#   'woodlands',
#   'energy',
#   'general',
#   'professional',
#   'human',
#   'resources',
#   'senior',
#   'professional',
#   'human',
#   'resources'],
#  ['human', 'resources', 'coordinator', 'intercontinental', 'atlanta'],
#  ['experienced',
#   'retail',
#   'manager',
#   'aspiring',
#   'human',
#   'resources',
#   'professional'],
#  ['human', 'resources', 'staffing', 'recruiting', 'professional'],
#  ['human', 'resources', 'specialist'],
#  ['director', 'human', 'resources', 'north', 'america', 'groupe'],
#  ['retired',
#   'army',
#   'national',
#   'guard',
#   'recruiter',
#   'office',
#   'manager',
#   'seeking',
#   'position',
#   'human',
#   'resources'],
#  ['human', 'resources', 'generalist', 'inc'],
#  ['business',
#   'management',
#   'major',
#   'aspiring',
#   'human',
#   'resources',
#   'manager'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'seeking',
#   'internship',
#   'human',
#   'resources'],
#  ['human', 'resources', 'professional'],
#  ['staffing',
#   'seeking',
#   'human',
#   'resources',
#   'payroll',
#   'administrative',
#   'professionals'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'passionate',
#   'helping',
#   'create',
#   'inclusive',
#   'engaging',
#   'work',
#   'environment'],
#  ['human',
#   'resources',
#   'conflict',
#   'management',
#   'policies',
#   'procedures',
#   'talent',
#   'management',
#   'benefits',
#   'compensation'],
#  ['human', 'resources', 'generalist'],
#  ['liberal', 'arts', 'major', 'aspiring', 'human', 'resources', 'analyst'],
#  ['junior', 'mes', 'engineer', 'information', 'systems'],
#  ['senior',
#   'human',
#   'resources',
#   'business',
#   'partner',
#   'heil',
#   'environmental'],
#  ['aspiring',
#   'human',
#   'resources',
#   'professional',
#   'energetic',
#   'team',
#   'focused',
#   'leader'],
#  ['human', 'resources', 'manager', 'shine', 'north', 'america'],
#  ['human', 'resources', 'professional', 'world', 'leader', 'gis', 'software'],
#  ['rrp',
#   'brand',
#   'portfolio',
#   'executive',
#   'japan',
#   'tobacco',
#   'international'],
#  ['information',
#   'systems',
#   'specialist',
#   'programmer',
#   'love',
#   'data',
#   'organization'],
#  ['bachelor', 'science', 'biology', 'victoria', 'university', 'wellington'],
#  ['human', 'resources', 'management', 'major'],
#  ['director', 'human', 'resources', 'ey'],
#  ['undergraduate', 'research', 'assistant', 'lab'],
#  ['lead', 'official', 'western', 'illinois', 'university'],
#  ['seeking',
#   'employment',
#   'opportunities',
#   'within',
#   'customer',
#   'service',
#   'patient',
#   'care'],
#  ['admissions',
#   'representative',
#   'community',
#   'medical',
#   'center',
#   'long',
#   'beach'],
#  ['seeking',
#   'human',
#   'resources',
#   'opportunities',
#   'open',
#   'travel',
#   'relocation'],
#  ['student', 'state', 'university'],
#  ['student',
#   'indiana',
#   'university',
#   'business',
#   'management',
#   'retail',
#   'manager',
#   'hardware',
#   'paint'],
#  ['aspiring', 'human', 'resources', 'professional'],
#  ['student'],
#  ['seeking', 'human', 'resources', 'position'],
#  ['aspiring',
#   'human',
#   'resources',
#   'manager',
#   'graduating',
#   'may',
#   'seeking',
#   'entry',
#   'level',
#   'human',
#   'resources',
#   'position',
#   'st',
#   'louis'],
#  ['human', 'resources', 'generalist'],
#  ['business', 'intelligence', 'analytics', 'travelers'],
#  ['always', 'set', 'success'],
#  ['director', 'administration', 'excellence', 'logging'],
#  ['seeking', 'human', 'resources']]

# %%
vectorizer = Vectorizer()
vectorizer.word2vec(job_desc_list, pretrained_vectors_path= './GoogleNews-vectors-negative300.bin')
word2vec_vectors = vectorizer.vectors

# %%
dist_1 = spatial.distance.cosine(word2vec_vectors[-1], word2vec_vectors[0])
dist_2 = spatial.distance.cosine(word2vec_vectors[-1], word2vec_vectors[2])
print('dist_1: {0}, dist-2: {1}'.format(dist_1, dist_2))
# Out:
# dist_1: 0.611827164888382, dist-2: 0.29940420389175415

# %%
vector_df = df
vector_df.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN

# %%
scores = []
for num in range(len(job_desc_list) - 1):
    scores.append(1 - spatial.distance.cosine(word2vec_vectors[num], word2vec_vectors[-1]))
    
vector_df['word2vec_fit'] = scores
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit  word2vec_fit
# 0                         Houston, Texas         85  NaN      0.388173
# 1                                 Kanada      500+   NaN      0.104410
# 2    Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 3                          Denton, Texas      500+   NaN      0.291818
# 4                         İzmir, Türkiye      500+   NaN      0.229988
# ..                                   ...        ...  ...           ...
# 99              Cape Girardeau, Missouri        103  NaN      0.729863
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 101           Greater New York City Area         49  NaN      0.282647
# 102             Greater Los Angeles Area      500+   NaN      0.133268
# 103                          Katy, Texas      500+   NaN      0.281777
#
# [104 rows x 6 columns]

# %%
vector_df.sort_values(by=['word2vec_fit'], ascending=False).head(15)
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 27    28              Seeking Human Resources Opportunities
# 29    30              Seeking Human Resources Opportunities
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 73    74                       Human Resources Professional
# 67    68            Human Resources Specialist at Luxottica
# 100  101              Human Resources Generalist at Loparex
# 77    78             Human Resources Generalist at Schwan's
# 87    88                   Human Resources Management Major
# 59    60                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
#
#                                 location connection  fit  word2vec_fit
# 98                Las Vegas, Nevada Area         48  NaN      0.920869
# 27                     Chicago, Illinois        390  NaN      0.903864
# 29                     Chicago, Illinois        390  NaN      0.903864
# 72                   Houston, Texas Area          7  NaN      0.839220
# 9              Greater Philadelphia Area      500+   NaN      0.808101
# 39             Greater Philadelphia Area      500+   NaN      0.808101
# 52             Greater Philadelphia Area      500+   NaN      0.808101
# 61             Greater Philadelphia Area      500+   NaN      0.808101
# 73                   Greater Boston Area         16  NaN      0.793325
# 67            Greater New York City Area      500+   NaN      0.767376
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 77           Amerika Birleşik Devletleri      500+   NaN      0.750962
# 87                  Milpitas, California         18  NaN      0.747540
# 59            Greater New York City Area          1  NaN      0.743151
# 5             Greater New York City Area          1  NaN      0.743151

# %% [markdown]
# ## BERT

# %%
bert_list = []

for num in range(len(df)):
    desc = df.iloc[num]['job_title']
    ## remove punctuation from job description    
    for symbol in list(string.punctuation):
        desc = desc.replace(symbol, ' ')
        
    ## write out acronyms for human resource positions
    desc = nltk.word_tokenize(desc)
    for word in range(len(desc)):
        if desc[word] == 'HR':
            desc[word] = 'Human Resources'
        elif desc[word] == 'CHRO':
            desc[word] = 'Chief Human Resources Officer'
        elif desc[word] == 'GPHR':
            desc[word] = 'General Professional in Human Resources'
        elif desc[word] == 'SPHR':
            desc[word] = 'Senior Professional in Human Resources'
    
    desc = ' '.join(desc)
    bert_list.append(desc)

# %%
bert_list.append('seeking human resources')

# %%
bert_list
# Out:
# ['2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Aspiring Human Resources Management student seeking an internship',
#  'Seeking Human Resources Opportunities',
#  'Aspiring Human Resources Management student seeking an internship',
#  'Seeking Human Resources Opportunities',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Native English Teacher at EPIK English Program in Korea',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Advisory Board Member at Celal Bayar University',
#  'Aspiring Human Resources Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Human Resources Senior Specialist',
#  'Student at Humber College and Aspiring Human Resources Generalist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  '2019 C T Bauer College of Business Graduate Magna Cum Laude and aspiring Human Resources professional',
#  'Aspiring Human Resources Professional',
#  'People Development Coordinator at Ryan',
#  'Aspiring Human Resources Specialist',
#  'Human Resources Senior Specialist',
#  'Seeking Human Resources HRIS and Generalist Positions',
#  'Student at Chapman University',
#  'SVP Chief Human Resources Officer Marketing Communications CSR Officer ENGIE Houston The Woodlands Energy General Professional in Human Resources Senior Professional in Human Resources',
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta',
#  'Experienced Retail Manager and aspiring Human Resources Professional',
#  'Human Resources Staffing and Recruiting Professional',
#  'Human Resources Specialist at Luxottica',
#  'Director of Human Resources North America Groupe Beneteau',
#  'Retired Army National Guard Recruiter office manager seeking a position in Human Resources',
#  'Human Resources Generalist at ScottMadden Inc',
#  'Business Management Major and Aspiring Human Resources Manager',
#  'Aspiring Human Resources Manager seeking internship in Human Resources',
#  'Human Resources Professional',
#  'Nortia Staffing is seeking Human Resources Payroll Administrative Professionals 408 709 2621',
#  'Aspiring Human Resources Professional Passionate about helping to create an inclusive and engaging work environment',
#  'Human Resources Conflict Management Policies Procedures Talent Management Benefits Compensation',
#  'Human Resources Generalist at Schwan s',
#  'Liberal Arts Major Aspiring Human Resources Analyst',
#  'Junior MES Engineer Information Systems',
#  'Senior Human Resources Business Partner at Heil Environmental',
#  'Aspiring Human Resources Professional An energetic and Team Focused Leader',
#  'Human Resources Manager at Endemol Shine North America',
#  'Human Resources professional for the world leader in GIS software',
#  'RRP Brand Portfolio Executive at JTI Japan Tobacco International',
#  'Information Systems Specialist and Programmer with a love for data and organization',
#  'Bachelor of Science in Biology from Victoria University of Wellington',
#  'Human Resources Management Major',
#  'Director Human Resources at EY',
#  'Undergraduate Research Assistant at Styczynski Lab',
#  'Lead Official at Western Illinois University',
#  'Seeking employment opportunities within Customer Service or Patient Care',
#  'Admissions Representative at Community medical center long beach',
#  'Seeking Human Resources Opportunities Open to travel and relocation',
#  'Student at Westfield State University',
#  'Student at Indiana University Kokomo Business Management Retail Manager at Delphi Hardware and Paint',
#  'Aspiring Human Resources Professional',
#  'Student',
#  'Seeking Human Resources Position',
#  'Aspiring Human Resources Manager Graduating May 2020 Seeking an Entry Level Human Resources Position in St Louis',
#  'Human Resources Generalist at Loparex',
#  'Business Intelligence and Analytics at Travelers',
#  'Always set them up for Success',
#  'Director Of Administration at Excellence Logging',
#  'seeking human resources']

# %%
vectorizer = Vectorizer()
vectorizer.bert(bert_list)
bert_vectors = vectorizer.vectors
# Out:
# Vectorization done on cpu device
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
dist_1 = spatial.distance.cosine(bert_vectors[-1], bert_vectors[0])
dist_2 = spatial.distance.cosine(bert_vectors[-1], bert_vectors[2])
print('dist_1: {0}, dist-2: {1}'.format(dist_1, dist_2))
# Out:
# dist_1: 0.07078111171722412, dist-2: 0.01500558853149414

# %%
scores = []
for num in range(len(bert_list) - 1):
    scores.append(1 - spatial.distance.cosine(bert_vectors[num], bert_vectors[-1]))
    
vector_df['bert_fit'] = scores
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit  word2vec_fit  \
# 0                         Houston, Texas         85  NaN      0.388173
# 1                                 Kanada      500+   NaN      0.104410
# 2    Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 3                          Denton, Texas      500+   NaN      0.291818
# 4                         İzmir, Türkiye      500+   NaN      0.229988
# ..                                   ...        ...  ...           ...
# 99              Cape Girardeau, Missouri        103  NaN      0.729863
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 101           Greater New York City Area         49  NaN      0.282647
# 102             Greater Los Angeles Area      500+   NaN      0.133268
# 103                          Katy, Texas      500+   NaN      0.281777
#
#      bert_fit
# 0    0.929219
# 1    0.948172
# 2    0.984994
# 3    0.973138
# 4    0.935457
# ..        ...
# 99   0.914459
# 100  0.982065
# 101  0.976543
# 102  0.983066
# 103  0.968243
#
# [104 rows x 7 columns]

# %%
vector_df.sort_values(by=['bert_fit'], ascending=False).head(15)
# Out:
#     id                              job_title  \
# 29  30  Seeking Human Resources Opportunities
# 27  28  Seeking Human Resources Opportunities
# 98  99       Seeking Human Resources Position
# 73  74           Human Resources Professional
# 87  88       Human Resources Management Major
# 5    6    Aspiring Human Resources Specialist
# 59  60    Aspiring Human Resources Specialist
# 35  36    Aspiring Human Resources Specialist
# 48  49    Aspiring Human Resources Specialist
# 23  24    Aspiring Human Resources Specialist
# 97  98                                Student
# 32  33  Aspiring Human Resources Professional
# 20  21  Aspiring Human Resources Professional
# 96  97  Aspiring Human Resources Professional
# 2    3  Aspiring Human Resources Professional
#
#                                location connection  fit  word2vec_fit  \
# 29                    Chicago, Illinois        390  NaN      0.903864
# 27                    Chicago, Illinois        390  NaN      0.903864
# 98               Las Vegas, Nevada Area         48  NaN      0.920869
# 73                  Greater Boston Area         16  NaN      0.793325
# 87                 Milpitas, California         18  NaN      0.747540
# 5            Greater New York City Area          1  NaN      0.743151
# 59           Greater New York City Area          1  NaN      0.743151
# 35           Greater New York City Area          1  NaN      0.743151
# 48           Greater New York City Area          1  NaN      0.743151
# 23           Greater New York City Area          1  NaN      0.743151
# 97                  Houston, Texas Area          4  NaN      0.123904
# 32  Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 20  Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 96                 Kokomo, Indiana Area         71  NaN      0.700596
# 2   Raleigh-Durham, North Carolina Area         44  NaN      0.700596
#
#     bert_fit
# 29  0.996201
# 27  0.996201
# 98  0.994894
# 73  0.991686
# 87  0.990193
# 5   0.987985
# 59  0.987985
# 35  0.987985
# 48  0.987985
# 23  0.987985
# 97  0.985903
# 32  0.984994
# 20  0.984994
# 96  0.984994
# 2   0.984994

# %% [markdown]
# ## TF-IDF

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(bert_list)

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
vector_df['tfidf_fit'] = cosine_sim[-1][:-1]

# %%
vector_df.sort_values(by=['tfidf_fit'], ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 27  28              Seeking Human Resources Opportunities
# 29  30              Seeking Human Resources Opportunities
# 98  99                   Seeking Human Resources Position
# 72  73  Aspiring Human Resources Manager, seeking inte...
# 52  53  Seeking Human Resources HRIS and Generalist Po...
# 9   10  Seeking Human Resources HRIS and Generalist Po...
# 61  62  Seeking Human Resources HRIS and Generalist Po...
# 39  40  Seeking Human Resources HRIS and Generalist Po...
# 26  27  Aspiring Human Resources Management student se...
# 28  29  Aspiring Human Resources Management student se...
# 73  74                       Human Resources Professional
# 93  94  Seeking Human  Resources Opportunities. Open t...
# 32  33              Aspiring Human Resources Professional
# 2    3              Aspiring Human Resources Professional
# 96  97              Aspiring Human Resources Professional
#
#                                location connection  fit  word2vec_fit  \
# 27                    Chicago, Illinois        390  NaN      0.903864
# 29                    Chicago, Illinois        390  NaN      0.903864
# 98               Las Vegas, Nevada Area         48  NaN      0.920869
# 72                  Houston, Texas Area          7  NaN      0.839220
# 52            Greater Philadelphia Area      500+   NaN      0.808101
# 9             Greater Philadelphia Area      500+   NaN      0.808101
# 61            Greater Philadelphia Area      500+   NaN      0.808101
# 39            Greater Philadelphia Area      500+   NaN      0.808101
# 26                  Houston, Texas Area      500+   NaN      0.696512
# 28                  Houston, Texas Area      500+   NaN      0.696512
# 73                  Greater Boston Area         16  NaN      0.793325
# 93          Amerika Birleşik Devletleri        415  NaN      0.726077
# 32  Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 2   Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 96                 Kokomo, Indiana Area         71  NaN      0.700596
#
#     bert_fit  tfidf_fit
# 27  0.996201   0.646155
# 29  0.996201   0.646155
# 98  0.994894   0.625865
# 72  0.975402   0.552318
# 52  0.974998   0.447527
# 9   0.974998   0.447527
# 61  0.974998   0.447527
# 39  0.974998   0.447527
# 26  0.965308   0.406702
# 28  0.965308   0.406702
# 73  0.991686   0.351856
# 93  0.969101   0.302663
# 32  0.984994   0.292820
# 2   0.984994   0.292820
# 96  0.984994   0.292820

# %% [markdown]
# ## GloVe

# %%
glove_list = []

for num in range(len(df)):
    desc = df.iloc[num]['job_title']
    ## remove punctuation from job description    
    for symbol in list(string.punctuation):
        desc = desc.replace(symbol, ' ')
        
    ## write out acronyms for human resource positions
    desc = nltk.word_tokenize(desc)
    for word in range(len(desc)):
        if desc[word] == 'HR':
            desc[word] = 'Human Resources'
        elif desc[word] == 'CHRO':
            desc[word] = 'Chief Human Resources Officer'
        elif desc[word] == 'GPHR':
            desc[word] = 'General Professional in Human Resources'
        elif desc[word] == 'SPHR':
            desc[word] = 'Senior Professional in Human Resources'
        elif desc[word] in ['HRIS', 'ENGIE', 'ScottMadden', 'Styczynski', 'Nortia', 'Loparex']:
            desc[word] = ''
        desc[word] = desc[word].lower()
    
    desc = [token for token in desc if token not in stopwords.words('english')]
    desc = [token for token in desc if not token.isdigit()]
    
    desc = ' '.join(desc)
    glove_list.append(desc)

glove_list.append('seeking human resources')
glove_list
# Out:
# ['c bauer college business graduate magna cum laude aspiring human resources professional',
#  'native english teacher epik english program korea',
#  'aspiring human resources professional',
#  'people development coordinator ryan',
#  'advisory board member celal bayar university',
#  'aspiring human resources specialist',
#  'student humber college aspiring human resources generalist',
#  'human resources senior specialist',
#  'student humber college aspiring human resources generalist',
#  'seeking human resources  generalist positions',
#  'student chapman university',
#  'svp chief human resources officer marketing communications csr officer  houston woodlands energy general professional in human resources senior professional in human resources',
#  'human resources coordinator intercontinental buckhead atlanta',
#  'c bauer college business graduate magna cum laude aspiring human resources professional',
#  'c bauer college business graduate magna cum laude aspiring human resources professional',
#  'native english teacher epik english program korea',
#  'aspiring human resources professional',
#  'people development coordinator ryan',
#  'c bauer college business graduate magna cum laude aspiring human resources professional',
#  'native english teacher epik english program korea',
#  'aspiring human resources professional',
#  'people development coordinator ryan',
#  'advisory board member celal bayar university',
#  'aspiring human resources specialist',
#  'student humber college aspiring human resources generalist',
#  'human resources senior specialist',
#  'aspiring human resources management student seeking internship',
#  'seeking human resources opportunities',
#  'aspiring human resources management student seeking internship',
#  'seeking human resources opportunities',
#  'c bauer college business graduate magna cum laude aspiring human resources professional',
#  'native english teacher epik english program korea',
#  'aspiring human resources professional',
#  'people development coordinator ryan',
#  'advisory board member celal bayar university',
#  'aspiring human resources specialist',
#  'student humber college aspiring human resources generalist',
#  'human resources senior specialist',
#  'student humber college aspiring human resources generalist',
#  'seeking human resources  generalist positions',
#  'student chapman university',
#  'svp chief human resources officer marketing communications csr officer  houston woodlands energy general professional in human resources senior professional in human resources',
#  'human resources coordinator intercontinental buckhead atlanta',
#  'c bauer college business graduate magna cum laude aspiring human resources professional',
#  'native english teacher epik english program korea',
#  'aspiring human resources professional',
#  'people development coordinator ryan',
#  'advisory board member celal bayar university',
#  'aspiring human resources specialist',
#  'student humber college aspiring human resources generalist',
#  'human resources senior specialist',
#  'student humber college aspiring human resources generalist',
#  'seeking human resources  generalist positions',
#  'student chapman university',
#  'svp chief human resources officer marketing communications csr officer  houston woodlands energy general professional in human resources senior professional in human resources',
#  'human resources coordinator intercontinental buckhead atlanta',
#  'c bauer college business graduate magna cum laude aspiring human resources professional',
#  'aspiring human resources professional',
#  'people development coordinator ryan',
#  'aspiring human resources specialist',
#  'human resources senior specialist',
#  'seeking human resources  generalist positions',
#  'student chapman university',
#  'svp chief human resources officer marketing communications csr officer  houston woodlands energy general professional in human resources senior professional in human resources',
#  'human resources coordinator intercontinental buckhead atlanta',
#  'experienced retail manager aspiring human resources professional',
#  'human resources staffing recruiting professional',
#  'human resources specialist luxottica',
#  'director human resources north america groupe beneteau',
#  'retired army national guard recruiter office manager seeking position human resources',
#  'human resources generalist  inc',
#  'business management major aspiring human resources manager',
#  'aspiring human resources manager seeking internship human resources',
#  'human resources professional',
#  ' staffing seeking human resources payroll administrative professionals',
#  'aspiring human resources professional passionate helping create inclusive engaging work environment',
#  'human resources conflict management policies procedures talent management benefits compensation',
#  'human resources generalist schwan',
#  'liberal arts major aspiring human resources analyst',
#  'junior mes engineer information systems',
#  'senior human resources business partner heil environmental',
#  'aspiring human resources professional energetic team focused leader',
#  'human resources manager endemol shine north america',
#  'human resources professional world leader gis software',
#  'rrp brand portfolio executive jti japan tobacco international',
#  'information systems specialist programmer love data organization',
#  'bachelor science biology victoria university wellington',
#  'human resources management major',
#  'director human resources ey',
#  'undergraduate research assistant  lab',
#  'lead official western illinois university',
#  'seeking employment opportunities within customer service patient care',
#  'admissions representative community medical center long beach',
#  'seeking human resources opportunities open travel relocation',
#  'student westfield state university',
#  'student indiana university kokomo business management retail manager delphi hardware paint',
#  'aspiring human resources professional',
#  'student',
#  'seeking human resources position',
#  'aspiring human resources manager graduating may seeking entry level human resources position st louis',
#  'human resources generalist ',
#  'business intelligence analytics travelers',
#  'always set success',
#  'director administration excellence logging',
#  'seeking human resources']

# %%
import gensim.downloader as api

model = api.load("glove-wiki-gigaword-300")

# %%
def preprocess(s):
    return [i.lower() for i in s.split()]

def get_vector(s):
    return np.sum(np.array([model[i] for i in preprocess(s)]), axis=0)

# %%
glove_vectors = []

for num in range(len(glove_list)):
    glove_vectors.append(get_vector(glove_list[num]))

# %%
scores = []
for num in range(len(glove_list) - 1):
    scores.append(1 - spatial.distance.cosine(glove_vectors[num], glove_vectors[-1]))
    
vector_df['glove_fit'] = scores
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit  word2vec_fit  \
# 0                         Houston, Texas         85  NaN      0.388173
# 1                                 Kanada      500+   NaN      0.104410
# 2    Raleigh-Durham, North Carolina Area         44  NaN      0.700596
# 3                          Denton, Texas      500+   NaN      0.291818
# 4                         İzmir, Türkiye      500+   NaN      0.229988
# ..                                   ...        ...  ...           ...
# 99              Cape Girardeau, Missouri        103  NaN      0.729863
# 100  Raleigh-Durham, North Carolina Area      500+   NaN      0.750962
# 101           Greater New York City Area         49  NaN      0.282647
# 102             Greater Los Angeles Area      500+   NaN      0.133268
# 103                          Katy, Texas      500+   NaN      0.281777
#
#      bert_fit  tfidf_fit  glove_fit
# 0    0.929219   0.097827   0.466585
# 1    0.948172   0.000000   0.329688
# 2    0.984994   0.292820   0.799220
# 3    0.973138   0.000000   0.529448
# 4    0.935457   0.000000   0.295936
# ..        ...        ...        ...
# 99   0.914459   0.283608   0.809268
# 100  0.982065   0.172445   0.810235
# 101  0.976543   0.000000   0.412289
# 102  0.983066   0.000000   0.459518
# 103  0.968243   0.000000   0.526039
#
# [104 rows x 9 columns]

# %%
vector_df.sort_values(by=['glove_fit'], ascending=False).head(15)
# Out:
#     id                                          job_title  \
# 29  30              Seeking Human Resources Opportunities
# 27  28              Seeking Human Resources Opportunities
# 98  99                   Seeking Human Resources Position
# 72  73  Aspiring Human Resources Manager, seeking inte...
# 52  53  Seeking Human Resources HRIS and Generalist Po...
# 9   10  Seeking Human Resources HRIS and Generalist Po...
# 39  40  Seeking Human Resources HRIS and Generalist Po...
# 61  62  Seeking Human Resources HRIS and Generalist Po...
# 73  74                       Human Resources Professional
# 87  88                   Human Resources Management Major
# 93  94  Seeking Human  Resources Opportunities. Open t...
# 5    6                Aspiring Human Resources Specialist
# 35  36                Aspiring Human Resources Specialist
# 59  60                Aspiring Human Resources Specialist
# 23  24                Aspiring Human Resources Specialist
#
#                        location connection  fit  word2vec_fit  bert_fit  \
# 29            Chicago, Illinois        390  NaN      0.903864  0.996201
# 27            Chicago, Illinois        390  NaN      0.903864  0.996201
# 98       Las Vegas, Nevada Area         48  NaN      0.920869  0.994894
# 72          Houston, Texas Area          7  NaN      0.839220  0.975402
# 52    Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 9     Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 39    Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 61    Greater Philadelphia Area      500+   NaN      0.808101  0.974998
# 73          Greater Boston Area         16  NaN      0.793325  0.991686
# 87         Milpitas, California         18  NaN      0.747540  0.990193
# 93  Amerika Birleşik Devletleri        415  NaN      0.726077  0.969101
# 5    Greater New York City Area          1  NaN      0.743151  0.987985
# 35   Greater New York City Area          1  NaN      0.743151  0.987985
# 59   Greater New York City Area          1  NaN      0.743151  0.987985
# 23   Greater New York City Area          1  NaN      0.743151  0.987985
#
#     tfidf_fit  glove_fit
# 29   0.646155   0.948254
# 27   0.646155   0.948254
# 98   0.625865   0.945992
# 72   0.552318   0.914078
# 52   0.447527   0.873041
# 9    0.447527   0.873041
# 39   0.447527   0.873041
# 61   0.447527   0.873041
# 73   0.351856   0.864729
# 87   0.183370   0.849824
# 93   0.302663   0.849721
# 5    0.261115   0.841785
# 35   0.261115   0.841785
# 59   0.261115   0.841785
# 23   0.261115   0.841785

# %%
vector_df.drop('fit', axis=1, inplace=True)
vector_df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  word2vec_fit  bert_fit  \
# 0                         Houston, Texas         85      0.388173  0.929219
# 1                                 Kanada      500+       0.104410  0.948172
# 2    Raleigh-Durham, North Carolina Area         44      0.700596  0.984994
# 3                          Denton, Texas      500+       0.291818  0.973138
# 4                         İzmir, Türkiye      500+       0.229988  0.935457
# ..                                   ...        ...           ...       ...
# 99              Cape Girardeau, Missouri        103      0.729863  0.914459
# 100  Raleigh-Durham, North Carolina Area      500+       0.750962  0.982065
# 101           Greater New York City Area         49      0.282647  0.976543
# 102             Greater Los Angeles Area      500+       0.133268  0.983066
# 103                          Katy, Texas      500+       0.281777  0.968243
#
#      tfidf_fit  glove_fit
# 0     0.097827   0.466585
# 1     0.000000   0.329688
# 2     0.292820   0.799220
# 3     0.000000   0.529448
# 4     0.000000   0.295936
# ..         ...        ...
# 99    0.283608   0.809268
# 100   0.172445   0.810235
# 101   0.000000   0.412289
# 102   0.000000   0.459518
# 103   0.000000   0.526039
#
# [104 rows x 8 columns]

# %% [markdown]
# ## RankNet

# %%
X = pd.DataFrame(word2vec_vectors)
y = vector_df['word2vec_fit']

# %%
X.drop([104], inplace=True)
X['qid'] = 1
qid = X['qid']
X.drop('qid', axis=1, inplace=True)

# %%
X
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.062602  0.059499  0.013392  0.121714 -0.008286  0.020477  0.097799
# 1    0.016439  0.023031  0.063843  0.074544  0.031146  0.078664  0.088704
# 2   -0.092773  0.037231  0.082809  0.029816 -0.020706  0.129272  0.140808
# 3   -0.050491  0.047333  0.044434  0.122192 -0.088943 -0.039001 -0.011597
# 4   -0.051636 -0.194458  0.125610  0.040283  0.007477 -0.017090  0.012085
# ..        ...       ...       ...       ...       ...       ...       ...
# 99  -0.043230  0.059992 -0.007956  0.068551 -0.028818  0.006404  0.054729
# 100  0.012126  0.026571  0.083333  0.181356 -0.121582  0.048340  0.282878
# 101  0.181854 -0.050110 -0.083588  0.055550 -0.091339  0.002075 -0.153183
# 102  0.012858  0.107290  0.022319  0.083171  0.132080 -0.069417  0.041829
# 103 -0.072128 -0.023636  0.035282  0.079102  0.069885 -0.081427 -0.028259
#
#           7         8         9    ...       290       291       292  \
# 0   -0.148356 -0.068639 -0.041682  ... -0.108190 -0.031993 -0.188354
# 1   -0.015747 -0.097514  0.070394  ... -0.070374  0.099121  0.027929
# 2   -0.086487 -0.114258 -0.032104  ... -0.119751 -0.025116 -0.212158
# 3   -0.158203 -0.051735 -0.092186  ...  0.006683  0.106628 -0.076370
# 4   -0.207157  0.087555 -0.115967  ...  0.041992 -0.043983 -0.144287
# ..        ...       ...       ...  ...       ...       ...       ...
# 99  -0.122018  0.012521  0.002887  ... -0.100917  0.020273 -0.124704
# 100 -0.080078 -0.018880 -0.111816  ... -0.131004 -0.089193 -0.243490
# 101  0.021851  0.176392 -0.056519  ...  0.102661  0.156403 -0.072754
# 102 -0.033203  0.125814  0.144613  ... -0.151367  0.051717 -0.107096
# 103 -0.081299  0.019096  0.006714  ... -0.082031  0.020020 -0.059113
#
#           293       294       295       296       297       298       299
# 0    0.020640  0.003052 -0.072347  0.014048 -0.025790 -0.016076  0.108134
# 1    0.025553 -0.006673 -0.075826 -0.082746  0.030599  0.004395  0.025146
# 2   -0.032745 -0.136597 -0.031494  0.108368 -0.043488 -0.089661  0.037567
# 3    0.084045 -0.046692 -0.178894  0.052185 -0.148071  0.028534  0.019531
# 4    0.130920  0.050659  0.089478 -0.059753  0.098572  0.075655 -0.086868
# ..        ...       ...       ...       ...       ...       ...       ...
# 99   0.023564 -0.027666  0.015769  0.072056 -0.062395 -0.036556  0.031067
# 100  0.131755 -0.111165  0.035156  0.136678 -0.098796  0.087484  0.057780
# 101  0.123596  0.133789  0.095886  0.148682  0.014404  0.132193  0.029694
# 102 -0.110026 -0.047201 -0.131673  0.133703  0.003845  0.003825 -0.129557
# 103  0.013282  0.062958 -0.085327  0.097977  0.017845  0.107117  0.141541
#
# [104 rows x 300 columns]

# %%
import tensorflow as tf
from tensorflow.keras import layers, activations, losses, Model, Input
from tensorflow.nn import leaky_relu
import numpy as np
from itertools import combinations
from tensorflow.keras.utils import plot_model, Progbar
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# model architecture
class RankNet(Model):
    def __init__(self):
        super().__init__()
        self.dense = [layers.Dense(16, activation=leaky_relu), layers.Dense(8, activation=leaky_relu)]
        self.o = layers.Dense(1, activation='linear')
        self.oi_minus_oj = layers.Subtract()
    
    def call(self, inputs):
        xi, xj = inputs
        densei = self.dense[0](xi)
        densej = self.dense[0](xj)
        for dense in self.dense[1:]:
            densei = dense(densei)
            densej = dense(densej)
        oi = self.o(densei)
        oj= self.o(densej)
        oij = self.oi_minus_oj([oi, oj])
        output = layers.Activation('sigmoid')(oij)
        return output
    
    def build_graph(self):
        x = [Input(shape=(10)), Input(shape=(10))]
        return Model(inputs=x, outputs=self.call(x))

# visualize model architecture
plot_model(RankNet().build_graph(), show_shapes=False)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
# put data into pairs
xi = []
xj = []
pij = []
pair_id = []
pair_query_id = []
for q in np.unique(qid):
    query_idx = np.where(qid == q)[0]
    for pair_idx in combinations(query_idx, 2):
        pair_query_id.append(q)
        
        pair_id.append(pair_idx)
        i = pair_idx[0]
        j = pair_idx[1]
        xi.append(X[i])
        xj.append(X[j])
        
        if y[i] == y[j]:
            _pij = 0.5
        elif y[i] > y[j]:
            _pij = 1
        else: 
            _pij = 0
        pij.append(_pij)
        
xi = np.array(xi)
xj = np.array(xj)
pij = np.array(pij)
pair_query_id = np.array(pair_query_id)

xi_train, xi_test, xj_train, xj_test, pij_train, pij_test, pair_id_train, pair_id_test = train_test_split(
    xi, xj, pij, pair_id, test_size=0.2, stratify=pair_query_id)

# %%
ranknet = RankNet()
ranknet.compile(optimizer='adam', loss='binary_crossentropy')
history = ranknet.fit([xi_train, xj_train], pij_train, epochs=50, batch_size=1, validation_data=([xi_test, xj_test], pij_test))
# Out:
# Epoch 1/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.5634 - val_loss: 0.4068
# Epoch 2/50
# 4284/4284 [==============================] - 4s 925us/step - loss: 0.3359 - val_loss: 0.2738
# Epoch 3/50
# 4284/4284 [==============================] - 4s 898us/step - loss: 0.2342 - val_loss: 0.1785
# Epoch 4/50
# 4284/4284 [==============================] - 4s 922us/step - loss: 0.1870 - val_loss: 0.1684
# Epoch 5/50
# 4284/4284 [==============================] - 4s 936us/step - loss: 0.1649 - val_loss: 0.1516
# Epoch 6/50
# 4284/4284 [==============================] - 4s 923us/step - loss: 0.1491 - val_loss: 0.1138
# Epoch 7/50
# 4284/4284 [==============================] - 4s 901us/step - loss: 0.1396 - val_loss: 0.1026
# Epoch 8/50
# 4284/4284 [==============================] - 4s 903us/step - loss: 0.1323 - val_loss: 0.0953
# Epoch 9/50
# 4284/4284 [==============================] - 4s 897us/step - loss: 0.1229 - val_loss: 0.0937
# Epoch 10/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.1190 - val_loss: 0.0995
# Epoch 11/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.1157 - val_loss: 0.1065
# Epoch 12/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.1165 - val_loss: 0.1080
# Epoch 13/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.1109 - val_loss: 0.1030
# Epoch 14/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.1091 - val_loss: 0.0905
# Epoch 15/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.1035 - val_loss: 0.1056
# Epoch 16/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.1001 - val_loss: 0.0938
# Epoch 17/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0984 - val_loss: 0.0753
# Epoch 18/50
# 4284/4284 [==============================] - 4s 999us/step - loss: 0.0963 - val_loss: 0.0817
# Epoch 19/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0970 - val_loss: 0.0981
# Epoch 20/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.1026 - val_loss: 0.0843
# Epoch 21/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0938 - val_loss: 0.1269
# Epoch 22/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0897 - val_loss: 0.0661
# Epoch 23/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0919 - val_loss: 0.0689
# Epoch 24/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0921 - val_loss: 0.0712
# Epoch 25/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0937 - val_loss: 0.0714
# Epoch 26/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0884 - val_loss: 0.0778
# Epoch 27/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0858 - val_loss: 0.0752
# Epoch 28/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0914 - val_loss: 0.1402
# Epoch 29/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0909 - val_loss: 0.0556
# Epoch 30/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0872 - val_loss: 0.0874
# Epoch 31/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0865 - val_loss: 0.0678
# Epoch 32/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0886 - val_loss: 0.0905
# Epoch 33/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0831 - val_loss: 0.1071
# Epoch 34/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0800 - val_loss: 0.0793
# Epoch 35/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0854 - val_loss: 0.0674
# Epoch 36/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0849 - val_loss: 0.0976
# Epoch 37/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0817 - val_loss: 0.0612
# Epoch 38/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0777 - val_loss: 0.0623
# Epoch 39/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0836 - val_loss: 0.0625
# Epoch 40/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0767 - val_loss: 0.0888
# Epoch 41/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0787 - val_loss: 0.0504
# Epoch 42/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0804 - val_loss: 0.0539
# Epoch 43/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0735 - val_loss: 0.0599
# Epoch 44/50
# 4284/4284 [==============================] - 5s 1ms/step - loss: 0.0805 - val_loss: 0.0963
# Epoch 45/50
# 4284/4284 [==============================] - 4s 1ms/step - loss: 0.0790 - val_loss: 0.0700
# Epoch 46/50
# 4284/4284 [==============================] - 4s 881us/step - loss: 0.0813 - val_loss: 0.0767
# Epoch 47/50
# 4284/4284 [==============================] - 4s 896us/step - loss: 0.0797 - val_loss: 0.0560
# Epoch 48/50
# 4284/4284 [==============================] - 4s 948us/step - loss: 0.0729 - val_loss: 0.0733
# Epoch 49/50
# 4284/4284 [==============================] - 4s 948us/step - loss: 0.0779 - val_loss: 0.0630
# Epoch 50/50
# 4284/4284 [==============================] - 4s 900us/step - loss: 0.0757 - val_loss: 0.0921

# %%
from LambdaRankNN  import RankNetNN

ranker = RankNetNN(input_size=X.shape[0])
ranker.fit(X, y, qid, epochs=10)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 1s 939us/step - loss: 0.6332
# Epoch 2/10
# 163/163 [==============================] - 0s 896us/step - loss: 0.5126
# Epoch 3/10
# 163/163 [==============================] - 0s 877us/step - loss: 0.4032
# Epoch 4/10
# 163/163 [==============================] - 0s 902us/step - loss: 0.3267
# Epoch 5/10
# 163/163 [==============================] - 0s 884us/step - loss: 0.2726
# Epoch 6/10
# 163/163 [==============================] - 0s 914us/step - loss: 0.2345
# Epoch 7/10
# 163/163 [==============================] - 0s 995us/step - loss: 0.2060
# Epoch 8/10
# 163/163 [==============================] - 0s 877us/step - loss: 0.1845
# Epoch 9/10
# 163/163 [==============================] - 0s 877us/step - loss: 0.1657
# Epoch 10/10
# 163/163 [==============================] - 0s 877us/step - loss: 0.1516
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12200/1734274247.py in <module>
#       2
#       3 ranker = RankNetNN(input_size=X.shape[0])
# ----> 4 ranker.fit(X, y, qid, epochs=10)
#
# ~\anaconda3\lib\site-packages\LambdaRankNN\__init__.py in fit(self, X, y, qid, batch_size, epochs, verbose, validation_split)
#     122         self.model.fit([X1_trans, X2_trans], y_trans, sample_weight=weight, batch_size=batch_size, epochs=epochs,
#     123                        verbose=verbose, validation_split=validation_split)
# --> 124         self.evaluate(X, y, qid)
#     125
#     126     def predict(self, X):
#
# ~\anaconda3\lib\site-packages\LambdaRankNN\__init__.py in evaluate(self, X, y, qid, eval_at)
#     154         ndcg@eval_at: float
#     155         """
# --> 156         y_pred = self.predict(X)
#     157         tmp = np.array(np.hstack([y.reshape(-1, 1), y_pred.reshape(-1, 1), qid.reshape(-1, 1)]))
#     158         tmp = tmp[np.lexsort((-tmp[:, 1], tmp[:, 2]))]
#
# ~\anaconda3\lib\site-packages\LambdaRankNN\__init__.py in predict(self, X)
#     136         """
#     137         ranker_output = K.function([self.model.layers[0].input], [self.model.layers[-3].get_output_at(0)])
# --> 138         return ranker_output([X])[0].ravel()
#     139
#     140     def evaluate(self, X, y, qid, eval_at=None):
#
# ~\anaconda3\lib\site-packages\keras\backend.py in func(model_inputs)
#    4320     wrap_outputs = isinstance(outputs, list) and len(outputs) == 1
#    4321     def func(model_inputs):
# -> 4322       outs = model(model_inputs)
#    4323       if wrap_outputs:
#    4324         outs = [outs]
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\engine\input_spec.py in display_shape(shape)
#     269
#     270 def display_shape(shape):
# --> 271   return str(tuple(shape.as_list()))
#     272
#     273
#
# AttributeError: 'tuple' object has no attribute 'as_list'
